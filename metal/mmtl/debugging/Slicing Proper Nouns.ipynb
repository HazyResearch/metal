# %% [markdown]
# ### Load all examples
#  * `generate_uids=True`: return UIDs per example
#  * `tokenizer=None`: return raw (untokenized) examples

# %%
from utils import *
pd.set_option('display.max_colwidth', -1)

# %%
from metal.mmtl.utils.preprocess import load_tsv, get_task_tsv_config

# %%
config = get_task_tsv_config('COLA', 'dev')
    
(examples, labels), uids = load_tsv(
    tsv_path=config["tsv_path"],
    sent1_idx=config["sent1_idx"],
    sent2_idx=config["sent2_idx"],
    label_idx=config["label_idx"],
    skip_rows=config["skip_rows"],
    tokenizer=None,
    delimiter="\t",
    label_fn=config["label_fn"],
    generate_uids=True
)

assert len(examples) == len(labels) == len(uids)
# Out:
# HBox(children=(IntProgress(value=0, max=1042), HTML(value='')))

# %% [markdown]
# ### Define Proper Nouns based on Entities
# Ref: https://spacy.io/api/annotation#named-entities

# %%
import spacy
nlp = spacy.load('xx_ent_wiki_sm')

def get_entities(sent, entities=["PER", "ORG", "LOC", "MISC"]):
    if sent is None:
        return []

    return [ent for ent in nlp(sent).ents if ent.label_ in entities]

def ex_has_proper_noun(ex):
    proper_nouns = get_entities(
        ex['sent1'], 
        entities=["PER", "ORG", "LOC", "MISC"]
    ) + get_entities(
        ex['sent2'], 
        entities=["PER", "ORG", "LOC", "MISC"]
    )

    return len(proper_nouns) > 0

def ex_has_loc(ex):
    locs = get_entities(ex['sent1'], entities=["LOC"]) \
        + get_entities(ex['sent2'], entities=["LOC"])
    return len(locs) > 0

def ex_has_loc_org(ex):
    locs = get_entities(ex['sent1'], entities=["LOC", "ORG"]) \
        + get_entities(ex['sent2'], entities=["LOC", "ORG"])
    return len(locs) > 0

# %% [markdown]
# ### Tag all examples in slice

# %%
from tagger import Tagger
tagger = Tagger(verbose=False)

# %%
slice_name = 'locs_orgs'
in_slice_fn = ex_has_loc_org

# %%
for idx, (ex, label, uid) in enumerate(zip(examples, labels, uids)):   
    # logging for sanity check
    if idx % 1000 == 0:
        print(uid)
        print(ex, label)
        print()  

    # if there are "proper nouns" as defined by entites, add the tag!
    if in_slice_fn(ex):
        tagger.add_tag(uid, slice_name)
# Out:
# CoLA/dev.tsv:2
# {'sent1': 'The weights made the rope stretch over the pulley.', 'sent2': None} 1
#
# CoLA/dev.tsv:1002
# {'sent1': "John's arriving dead surprised me.", 'sent2': None} 1

# %%
num_in_slice = len(tagger.get_uids(slice_name))
num_ex = len(examples)
print(f"% in slice ({num_in_slice}/{num_ex}) {num_in_slice/num_ex}")
# Out:
# % in slice (279/1042) 0.2677543186180422

# %%
tagger.get_examples(slice_name)
# Out:
# Error: 278 RTE/dev.tsv:278
# [('CoLA/dev.tsv:1027',
#   {'sent1': 'I gave it to Pete to take to the fair.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:124',
#   {'sent1': 'No writer, nor any playwright, meets in Vienna.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:125',
#   {'sent1': 'That you will marry any student is not certain.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:131',
#   {'sent1': 'The worker will have a job.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:172',
#   {'sent1': 'Packages drive easily to New York.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:173',
#   {'sent1': 'The chair pushed.', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:195',
#   {'sent1': 'Ellen said that melons were selling well.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:200',
#   {'sent1': 'Paul laughed at Mary.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:23',
#   {'sent1': 'Mickey looked up it.', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:257',
#   {'sent1': 'John paid me against the book.', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:261',
#   {'sent1': "Students studying English reads Conrad's Heart of Darkness while at university.",
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:279',
#   {'sent1': 'John can kick the ball.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:289',
#   {'sent1': 'They love to play golf, but I do not.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:294',
#   {'sent1': 'Somebody apparently struck the unidentified victim during the early morning hours.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:302',
#   {'sent1': 'How did you guess that he fixed the computer?',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:316',
#   {'sent1': 'That we invaded Iraq really bites.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:317',
#   {'sent1': 'It annoys me that Fido barks.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:341',
#   {'sent1': "Hopefully, we'll make it through the winter without snow.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:351',
#   {'sent1': 'the one with a red cover takes a very long time to read.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:397',
#   {'sent1': 'In which car was the man seen?', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:413',
#   {'sent1': 'Who did John send the book?', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:415',
#   {'sent1': 'Came right in he did without so much as a knock.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:435',
#   {'sent1': 'This girl in the red coat will put a picture of Bill in the mailbox and on your desk before tomorrow.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:439',
#   {'sent1': 'John became deadly afraid of flying.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:447',
#   {'sent1': 'The soup cooks, thickens.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:46',
#   {'sent1': 'It is nice to go abroad.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:469',
#   {'sent1': 'John promise Mary to shave himself.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:489',
#   {'sent1': 'Medea denied poisoning the phoenix.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:492',
#   {'sent1': 'What did you ask who Medea gave?', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:506',
#   {'sent1': 'Jason happens to appear to seem to be sick.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:557',
#   {'sent1': 'Most columnists claim that a senior White House official has been briefing them, but none will reveal which one.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:558',
#   {'sent1': "Bill wondered how many papers Sandy had read, but he didn't care which ones.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:587',
#   {'sent1': "It has been determined that somebody will be appointed; it's just not clear yet who.",
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:590',
#   {'sent1': "Sandy is very anxious to see if the students will be able to solve the homework problem in a particular way, but she won't tell us which.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:629',
#   {'sent1': 'It was believed by the students that they would have an exam.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:654',
#   {'sent1': 'Harry told Sue that Albania is a lovely place for a vacation, and Tom.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:655',
#   {'sent1': 'Max seemed to be trying to begin to love Harriet, and Fred to be trying to begin to love Sue.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:659',
#   {'sent1': 'Millie will send the President an obscene telegram, and Paul, the Secretary a rude letter.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:665',
#   {'sent1': "Bill's story about Sue and Max's about Kathy both amazed me.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:667',
#   {'sent1': "Scientists at the South Hanoi Institute of Technology have succeeded in raising one dog with five legs, another with a cow's liver, and a third with no head.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:668',
#   {'sent1': "Bill's story about Sue may be amazing, but Max's is virtually incredible.",
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:672',
#   {'sent1': "As a teacher, you have to deal simultaneously with the administration's pressure on you to succeed, and the children's to be a nice guy.",
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:704',
#   {'sent1': 'Mary arranged for, in St. Louis, John to rent a house cheap.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:705',
#   {'sent1': 'It would be unwise for there to be no fire exit.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:738',
#   {'sent1': 'We like ourselves.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:76',
#   {'sent1': 'I want that Bill left to remain a secret.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:8',
#   {'sent1': 'The angrier Mary got, the more she looked at pictures.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:805',
#   {'sent1': 'The love of my life and mother of my children would never do such a thing.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:81',
#   {'sent1': 'I feel that Arch will show up.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:836',
#   {'sent1': 'We relied above Leslie.', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:837',
#   {'sent1': 'We celebrated in the streets.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:865',
#   {'sent1': 'Kim likes dogs.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:89',
#   {'sent1': 'I live at the place where Route 150 crosses the Hudson River and my dad lives at it too.',
#    'sent2': None,
#    'label': '0'}),
#  ('CoLA/dev.tsv:890',
#   {'sent1': 'Dana walking and Leslie running.', 'sent2': None, 'label': '0'}),
#  ('CoLA/dev.tsv:90',
#   {'sent1': 'Who is she trying to make up to now?',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:92',
#   {'sent1': 'Mike talked about politics yesterday to my friends.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:928',
#   {'sent1': 'It is obvious that Pat is lying.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:941',
#   {'sent1': 'That dogs bark annoys people.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:958',
#   {'sent1': 'Advantage is taken of every opportunity for improvement.',
#    'sent2': None,
#    'label': '1'}),
#  ('CoLA/dev.tsv:959',
#   {'sent1': 'The bucket was kicked by Pat.', 'sent2': None, 'label': '1'}),
#  ('CoLA/dev.tsv:972',
#   {'sent1': 'John gave Bill the dog dead.', 'sent2': None, 'label': '1'}),
#  ('RTE/dev.tsv:10',
#   {'sent1': 'Traditionally, the Brahui of the Raisani tribe are in charge of the law and order situation through the Pass area. This tribe is still living in present day Balochistan in Pakistan.',
#    'sent2': 'The Raisani tribe resides in Pakistan.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:100',
#   {'sent1': "Former WBA heavyweight champ Greg Page, who suffered a severe brain injury in a 2001 fight, has died at his Louisville home at the age of 50. According to Page's wife, the ex-champ died from complications due to boxing injuries and paralysis. Following a successful amateur career, Page went 58-17-1 during a professional career that began in 1979 and included wins over Jimmy Young, James Tillis, Renaldo Snipes, Gerrie Coetzee (for the WBA title), James 'Bonecrusher' Smith and Tim Witherspoon. Page's losses read like a who's who of heavyweights of the 1980s: Trevor Berbick, Witherspoon, Tony Tubbs, Buster Douglas, Joe Bugner, Orlin Norris, Donovan 'Razor' Ruddock, Bruce Seldon, Monte Barrett and Jorge Luis Gonzalez.",
#    'sent2': 'Greg Page was a boxer.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:101',
#   {'sent1': 'Prince Charles, Britain\'s heir to the throne, has announced that he is to wed his lover of 34 years, Camilla Parker Bowles. In a press statement, the Prince of Wales said "Mrs Parker Bowles and I are absolutely delighted. It will be a very special day for us and our families." Mrs Parker Bowles will use the title "HRH The Duchess of Cornwall" after their marriage, and it is intended that following the Prince\'s accession to the throne, Mrs Parker Bowles will use the title "HRH The Princess Consort". The pair are to marry on 8th April 2005 at a private civil ceremony in Windsor Castle, which will be an occasion primarily for friends and family. There will then be a service of prayer and dedication in St. George\'s Chapel, to be conducted by the Archbishop of Canterbury, Dr. Rowan Williams.',
#    'sent2': "Camilla Parker Bowles is engaged to Britain's heir.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:102',
#   {'sent1': 'The Kota ( "Fort" ), or Old City, for example, sometimes called the downtown section, is the central business district and Indonesia\'s financial capital.',
#    'sent2': "The Kota is the country's business center.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:103',
#   {'sent1': 'Known as "heap leach" mining, the method has become popular in the last decade because it enables microscopic bits of gold to be economically extracted from low-grade ore.',
#    'sent2': 'The mining industry uses a method known as heap leaching.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:105',
#   {'sent1': 'The U.S. Army acceded to a request from the local governor to keep U.S. troops away from the Imam Ali Shrine in Najaf.',
#    'sent2': 'The U.S. Army agreed to a request from the local governor to keep US troops away from the Imam Ali Shrine in Najaf.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:106',
#   {'sent1': 'The government of El Salvador strongly condemns the terrorist attacks carried out with explosives, today, against the Salvadoran Workers National Union Federation, in which several persons were wounded and others died.',
#    'sent2': 'Terrorist attacks were carried out in El Salvador.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:107',
#   {'sent1': 'MIDWEST CITY, Okla. -- Fire crews in Oklahoma and Texas raced Thursday to control wind-whipped wildfires that destroyed dozens of homes, seriously injured two people, forced evacuations and shut down parts of a major highway. Howling wind that had gusted to more than 60 mph grounded firefighting efforts by air in both states and drove blazes that scorched neighborhoods like "a war zone," Midwest City police Chief Brandon Clabes said. "The wind is the biggest issue, because we can\'t get ahead of the fires," Midwest City Fire Marshal Jerry Lojka said. By nightfall, wind gusts dropped to about 30 mph in many areas.',
#    'sent2': 'Homes were destroyed by wildfires in Oklahoma and Texas.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:108',
#   {'sent1': 'New security steps taken by the Customs Service may not be enough to stop a terrorist from smuggling in nuclear weapons.',
#    'sent2': 'Steps are being taken to stop the smuggling of aliens.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:109',
#   {'sent1': "The drugs that slow down or halt Alzheimer's disease work best the earlier you administer them.",
#    'sent2': "Alzheimer's disease is treated using drugs.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:11',
#   {'sent1': 'The international humanitarian aid organization, Doctors Without Borders/Medecins Sans Frontieres (MSF), continues to treat victims of violence in all locations where it is present in Darfur.',
#    'sent2': 'Doctors Without Borders is an international aid organization.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:111',
#   {'sent1': "Ren and Stimpy. Bugs Bunny. Philip J. Fry and Professor Hubert Farnsworth on Futurama. Sparx. Bi-Polar Bear. Popeye the Sailor Man. Woody Woodpecker. You may not think you have ever heard Billy West, but chances are on a television program, a movie, a commercial, or as Howard Stern's voice guru in the 1990's, you have heard him. West's talent for creating personalities by twisting his voice has made him one of a handful of voice actors - Hank Azaria and the late Mel Blanc come to mind - who have achieved celebrity for their talent. Indeed, West is one of the few voice actors who can impersonate Blanc in his prime, including characterizations of Bugs Bunny, Daffy Duck, Elmer Fudd and other characters from Warner Bros. cartoons.",
#    'sent2': 'Bugs Bunny is owned by Warner Bros.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:112',
#   {'sent1': "We learn that Claretta Petacci, Mussolini's last mistress, had a tendency to whine and to lie all day in bed, eating chocolate.",
#    'sent2': "Claretta Petacci was Mussolini's last mistress.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:114',
#   {'sent1': 'Both sides of this argument are presented in this paper, but it is the attempt of this paper to emphasize that the legalization of drugs would be destructive to our society.',
#    'sent2': 'Drug legalization has benefits.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:116',
#   {'sent1': 'Some of the buildings around the city square in the Kota also date from colonial times, including the old city hall ( 1710 ), which has been restored and now serves as the municipal museum.',
#    'sent2': 'The city hall is a museum now.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:117',
#   {'sent1': 'Meadows scored a bit part in a January episode of "Law & Order".',
#    'sent2': 'Meadows appeared in a "Law & Order" episode which aired in January.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:119',
#   {'sent1': 'Grieving father Christopher Yavelow hopes to deliver one million letters to the queen of Holland to bring his children home.',
#    'sent2': 'Christopher Yavelow is the queen of Holland.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:12',
#   {'sent1': 'In a bowl, whisk together the eggs and sugar until completely blended and frothy.',
#    'sent2': 'In a bowl, whisk together the egg, sugar and vanilla until light in color.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:120',
#   {'sent1': 'When Albright was the US ambassador to the United Nations, Lesley Stahl of "60 Minutes" asked her about the sanctions and the deaths of Iraqi children. Albright said it was America\'s responsibility to make sure the Gulf War did not have to be fought again.',
#    'sent2': 'Albright said that to punish Saddam Hussein, the deaths of those children were "worth it."',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:121',
#   {'sent1': 'Unwilling to surrender his dream of beginning a Holy Land pilgrimage in Iraq, Pope John Paul II made a "virtual pilgrimage" Wednesday to Ur, the ancient city that is traditionally held to be the birthplace of Abraham.',
#    'sent2': 'Pope John Paul II was born in Poland.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:122',
#   {'sent1': 'We look at the cool relationship between these two establishment families and how the party would fare with the son, Texas Gov. George W. Bush, and the wife, Elizabeth Dole, on the 2000 campaign trail.',
#    'sent2': "The name of George W. Bush's wife is Laura.",
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:123',
#   {'sent1': 'As regards the headquarters building, the Swiss are stipulating that they would transfer it to the WTO for a value of about 51 million swiss franks.',
#    'sent2': 'The WTO headquarters are in Switzerland.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:124',
#   {'sent1': 'A plane crashed in North Carolina last year and most of the Blink-182 group was in there. The only survivors of the crash were DJ AM and musical partner Travis Barker. Less lucky, "Lil" Chris Baker, Barker\'s close friend and assistant, the Blink-182 drummer\'s bodyguard, Charles "Che" Still, the pilot and co-pilot died. Both AM and Barker suffered many injures, bad burns and they needed to stay in hospital for several weeks. Now AM asks $20 million in compensation for injuries he suffered. He lawsuits against plane maker Learjet and wants to gain $10 million for medical damages, lost earnings and profit and the same amount for mental and physical suffering.',
#    'sent2': 'Travis Barker belongs to a band.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:125',
#   {'sent1': 'VCU School of the Arts In Qatar is located in Doha, the capital city of Qatar.',
#    'sent2': 'Qatar is located in Doha.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:126',
#   {'sent1': "Pole Robert Kubica became the highlight of the weekend by winning the pole, but was slow off the start and finished third on the podium. Nick Heidfeld, his BMW Sauber teammate finished fourth. The results puts BMW as the new leader of the Constructors' championship, one point ahead of Scuderia Ferrari. Heikki Kovalainen came fifth and became the only McLaren driver to finish in the points. Jarno Trulli (Toyota) and Mark Webber (Red Bull-Renault) ran 6 and 7 places respectively with Nico Rosberg (Williams-Toyota) closing out the top eight with 1 point. Timo Glock (Toyota) was engaged in a hard battle with Fernando Alonso (Renault) and came 9th ahead of the Spanish 2005 F1 Champion.",
#    'sent2': 'Robert Kubica has been appointed by Scuderia Ferrari.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:127',
#   {'sent1': 'Confident that those grading papers would understand answers written in text-speak, Haque stressed that in some exams, including English, text abbreviations would be penalized.',
#    'sent2': 'Haque wants to include English in some exams.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:129',
#   {'sent1': "Cote d'Ivoire's President, Laurent Gbagbo, promulgated new election laws on July 14.",
#    'sent2': "President Laurent Gbagbo lives in Cote d'Ivoire.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:133',
#   {'sent1': 'The provincial veterinarian with the Department of Forest Resources and Agrifoods, Dr. Hugh Whitney, confirmed today another case of rabies in Labrador, bringing the total number of confirmed rabies cases to nine in Labrador since November 2000.',
#    'sent2': 'A case of rabies was confirmed.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:134',
#   {'sent1': 'An American journalist of Russian descent, Klebnikov was shot four times by at least one assassin in a passing car as he stepped outside his office that evening in Moscow.',
#    'sent2': 'Vladislav Listyev was murdered in Moscow.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:135',
#   {'sent1': 'A powerful typhoon battered the northern and central Philippines with rains and winds Thursday, killing at least three people and cutting off roads. Authorities canceled flights and ferry service and shut down schools. Typhoon Xangsane, packing winds of 81 mph made landfall overnight in the Bicol central region and was forecast to pass through the capital Manila, the Philippine weather bureau said.',
#    'sent2': 'A typhoon batters the Philippines.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:136',
#   {'sent1': 'Mount Olympus towers up from the center of the earth.',
#    'sent2': 'Mount Olympus is in the center of the earth.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:137',
#   {'sent1': "Philadelphia is considered the birthplace of the United States of America, where the Declaration of Independence and Constitution were written and signed in the city's Independence Hall.",
#    'sent2': 'The US Declaration of Independence is located in Philadelphia.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:138',
#   {'sent1': '"It\'s Only a Play" is Terrence McNally\'s "Give My Regards to Broadway," a lightweight tribute to the theater as seen from the lofty but limited vantage point of Broadway artists who are consumed by New York\'s hit/flop mentality.',
#    'sent2': 'Broadway is in New York.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:139',
#   {'sent1': 'Note that SBB, CFF and FFS stand out for the main railway company, in German, French and Italian.',
#    'sent2': 'The French railway company is called SNCF.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:14',
#   {'sent1': 'A jury is slated to decide for the first time whether Jack Kevorkian, famed as "Dr. Death," has violated Michigan\'s assisted-suicide ban, while the state continues to grapple with the issue of what to allow when the ill want to end their pain by ending their lives.',
#    'sent2': 'Jack Kevorkian is the real name of "Dr. Death".',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:140',
#   {'sent1': 'Los Angeles County probation officials say they are now studying how other counties recover juvenile detention costs, after admitting they mistakenly billed parents for days when youths were held in probation camps and halls. By law, California counties can bill parents and legal guardians for some daily costs of detaining youths, but only those whose parents can afford to pay. Last year, more than 20,000 youths were admitted to probation camps and halls, and L.A. County billed parents a daily charge of $11.94 for camps, $23.63 for halls.',
#    'sent2': 'In Los Angeles County all parents have to pay the detention costs of their children.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:141',
#   {'sent1': 'The witness then spotted Rodriguez crouching behind a gate for protection.',
#    'sent2': 'The witness rescued Rodriguez.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:144',
#   {'sent1': 'Blair has sympathy for anyone who has lost their lives in Iraq.',
#    'sent2': 'Blair is sympathetic to anyone who has lost their lives in Iraq.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:145',
#   {'sent1': "Mrs. Bush's approval ratings have remained very high, above 80%, even as her husband's have recently dropped below 50%.",
#    'sent2': '80% approve of Mr. Bush.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:149',
#   {'sent1': 'Moscow believes that the waters of the Sea of Azov should remain in common use, but Kiev insists on a clear division.',
#    'sent2': 'There is a territorial waters dispute.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:15',
#   {'sent1': 'Take consumer products giant Procter and Gamble. Even with a $1.8 billion Research and Development budget, it still manages 500 active partnerships each year, many of them with small companies.',
#    'sent2': 'Procter and Gamble spends $1.8 billion for Research and Development.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:150',
#   {'sent1': 'Jerry Reinsdorf (born February 25 1936 in Brooklyn, New York) is the owner of Chicago White Sox and the Chicago Bulls. Recently, he helped the White Sox win the 2005 World Series and, in the process, collected his seventh championship ring overall (the first six were all with the Bulls in the 1990s), becoming the third owner in the history of North American sports to win a championship in two different sports.',
#    'sent2': 'Jerry Reinsdorf has won 7 championships.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:151',
#   {'sent1': 'Quebec woman and her mother accused of plotting to kill a four-year-old girl.',
#    'sent2': 'Quebec woman murdered a four-year-old girl.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:154',
#   {'sent1': "A new study conducted by researchers from University of Otago's Christchurch School of Medicine has found that certain chemical compounds naturally found in cruciferous vegetables help kill cancer cells that are particularly resistant to chemotherapy. The study has been published in Cancer Research. The research team found that chemicals called isothiocyanates cause cancer cells to commit suicide. This includes cells with high levels of the protein Bcl-2, which makes them resistant to chemotherapy. Isothiocyanates are naturally found in cruciferous vegetables. These include kale, cabbage, broccoli, cauliflower, bok choy, radish, and watercress, among others.",
#    'sent2': 'Broccoli contains isothiocyanates.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:155',
#   {'sent1': 'Swedish massage is used to help relax muscles, increase circulation, remove metabolic waste products, help the recipient obtain a feeling of connectedness, a better awareness of their body and the way they use and position it.',
#    'sent2': 'Swedish massage loosens tense muscles.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:157',
#   {'sent1': 'The investigation came about following the collapse of Barings Bank, when one of its traders based in Singapore, Nick Leeson, amassed losses of the order of 600-700 million without the bank being aware of it.',
#    'sent2': 'Nick Leeson was arrested for collapse of Barings Bank PLC.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:158',
#   {'sent1': 'Rotorua has banned criminals with five or more dishonesty convictions from entering the Central Business District (CBD). The criminals will be issued with trespass notices banning them from the main streets of Rotorua. Eleven out of twelve councillors, including the Rotorua mayor, supported the by-law along with support from the police. Kevin Winters, Mayor of Rotorua, said "The ban also had the support of local businesses, who wanted an end to the thefts, assaults, shoplifting and other street crime on Rotorua streets. Crime was an issue in the area. Five strikes and you\'re out."',
#    'sent2': 'The Central Business District (CBD) is part of Rotorua.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:159',
#   {'sent1': 'Tropical storm Koni dumped significant rains on the Philippines before becoming a minimal typhoon and eventually making landfall on the northern coast of Vietnam.',
#    'sent2': 'A tropical storm has caused significant property damage.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:16',
#   {'sent1': 'Deceased U.S. soldiers and their effects were evacuated to Japan and then shipped home in refrigerated containers for interment in the U.S.',
#    'sent2': 'The U.S. military evacuated U.S. citizens.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:160',
#   {'sent1': 'Cancer Research Campaign signed a deal with a US pharmaceuticals company to develop a pioneering cancer treatment.',
#    'sent2': 'Other changes involve joint Research and Development programs with other companies.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:161',
#   {'sent1': 'COLOMBO (Reuters) - At least five people were killed and 11 wounded when a suspected Tamil Tiger suicide bomber blew herself up inside a police station in the Sri Lankan capital on Wednesday, shattering more than two years of relative peace.',
#    'sent2': 'People were killed in Tamil suicide attacks.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:162',
#   {'sent1': 'It has been observed that in those countries of the world where capital punishment is still in operation, the crime rate, especially murder, is distinctively low in comparison to countries where capital punishment has been discarded.',
#    'sent2': 'Capital punishment is a deterrent to crime.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:164',
#   {'sent1': 'Romano Prodi will meet the US President George Bush in his capacity as president of the European commission.',
#    'sent2': 'Romani Prodi is the US President.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:165',
#   {'sent1': "Thompson, a renegade journalist whose 'gonzo' style threw out any pretense at objectivity and established the hard-living writer as a counter-culture icon, fatally shot himself at his Colorado home on Sunday night, police said.",
#    'sent2': "Thompson's 'gonzo' journalism throws objectivity out of the window.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:166',
#   {'sent1': 'Ahern, who was travelling to Tokyo for an EU-Japan summit yesterday, will consult with other EU leaders by telephone later this week in an effort to find an agreed candidate.',
#    'sent2': 'A summit between Europe and Japan is taking place in the Japanise capital.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:167',
#   {'sent1': 'General Miguel Maza Marquez, chief of the Colombian Administrative Department Of Security (DAS), today confirmed foreign participation in the assassination of Luis Carlos Galan, senator and Liberal party presidential candidate, on 18 August in Bogota.',
#    'sent2': 'General Miguel Maza Marquez took part in the assassination of Luis Carlos Galan.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:168',
#   {'sent1': "Today's best estimate of giant panda numbers in the wild is about 1,100 individuals living in up to 32 separate populations mostly in China's Sichuan Province, but also in Shaanxi and Gansu provinces.",
#    'sent2': 'There are 32 pandas in the wild in China.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:169',
#   {'sent1': 'There has been a lot of concern over the rise of drug-resistant bacteria.',
#    'sent2': 'Bacteria is winning the war against antibiotics.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:17',
#   {'sent1': 'Mice given a substance found in red wine lived longer despite a fatty diet, a study shows.',
#    'sent2': 'Mice fed with red wine lived longer despite a fatty diet.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:171',
#   {'sent1': 'Coextensive with the metropolitan district of Jakarta Raya, it lies at the mouth of the Ciliwung ( Liwung River ) on the northwest coast of Java.',
#    'sent2': 'Jakarta lies at the mouth of the Ciliwung ( Liwung River ) on the northwest coast of the island of Java.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:172',
#   {'sent1': 'P. Prayong, who like Kevala belongs to the Theravada sect of Buddhism, chose India over other Buddhist majority nations as it is the birthplace of Gautama Buddha.',
#    'sent2': 'P. Prayong is a member of Theravada.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:173',
#   {'sent1': 'The memo, written by Marc Allen Connelly (who was general counsel to the funeral services commission at the time) and sent to Dick McNeil (the Bush-appointed chairman of the funeral commission), stated that Connelly "received information" from Texas state officials that two of the funeral commissioners worked for SCI.',
#    'sent2': 'Marc Allen Connelly worked for SCI.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:174',
#   {'sent1': 'A U.S. Court of Appeals on Friday has declared unconstitutional California Assembly Bills 1792 & 1793, the California "ultraviolent video games law" that sought to ban the sale or rental of violent video games to minors. Federal judge Consuelo M. Callahan has ruled that the 2005 statewide ban, which has yet to be enforced, violates minors\' rights under the US Constitution\'s First and 14th amendment because even the most graphic on-screen mayhem, video game content represents free speech that cannot be censored without proper justification.',
#    'sent2': 'California Assembly Bills 1792 & 1793 are laws against ultraviolent video games.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:175',
#   {'sent1': 'A farmer who was in contact with cows suffering from BSE -- the so-called mad cow disease -- has died from what is regarded as the human form of the disease.',
#    'sent2': 'Bovine spongiform encephalopathy is another name for the "mad cow disease".',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:177',
#   {'sent1': "US President Barack Obama has been sketching out the future direction of his administration, in events to mark his first 100 days in office. Mr Obama addressed a town hall meeting in St Louis before holding a primetime news conference, broadcast live on most US TV networks. Traditionally, commentators have used the milestone to assess presidents' early successes and failures. Latest polls suggest Mr Obama continues to enjoy a high level of popularity.",
#    'sent2': 'Barack Obama has been President of the U.S. for 100 days.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:178',
#   {'sent1': 'Blair has sympathy for anyone who has lost their lives in Iraq.',
#    'sent2': 'Blair is sorry for anyone who has lost their lives in Iraq.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:179',
#   {'sent1': 'While Bush was in the air, the White House was evacuated, with many employees running away from the premises on orders from Secret Service agents.',
#    'sent2': 'The U.S. military evacuated U.S. citizens.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:180',
#   {'sent1': 'About half were along a 20-mile stretch of Santa Monica Bay from Topanga Canyon Boulevard to the Palos Verdes Peninsula.',
#    'sent2': 'The coastline of Santa Monica Bay is 50 miles long.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:181',
#   {'sent1': 'The beleaguered Euro-Disney theme park outside Paris is doing so poorly it might have to close unless it gets help soon from its lenders, the chairman of Walt Disney Co. said in an interview published Friday.',
#    'sent2': 'Euro-Disney is a theme park outside Paris.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:182',
#   {'sent1': 'Four days of talks got underway with the US announcing the first significant overture to North Korea since George W Bush took office three years ago.',
#    'sent2': 'George W. Bush entered the US presidency 3 years ago.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:183',
#   {'sent1': '"The professoressa is a bit tired," an adviser to Rita Levi-Montalcini warned me as I prepared to interview Italy\'s Nobel prize-winning Life Senator on the eve of her 100th birthday. "Don\'t wear her out." I arrive to find the professoressa, as she is universally known, in the dress shop below her office in Rome, in an elegant black dress buttoned to the neck and a gold brooch of her own design, white hair immaculately coiffed, examining the rails of clothes with close and lively attention.',
#    'sent2': 'Rita Levi-Montalcini is a global expert on the brain.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:184',
#   {'sent1': 'Jean-Claude Trichet, the European Central Bank president, made it clear, on Wednesday, that he would oppose unwarranted political attempts to remove Antonio Fazio: the Bank of Italy governor, engulfed in controversy over his handling of bank takeover bids.',
#    'sent2': 'Antonio Fazio is subordinate to Jean-Claude Trichet.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:185',
#   {'sent1': 'He said that "there is evidence that Cristiani was involved in the murder of the six Jesuit priests" which occurred on 16 November in San Salvador.',
#    'sent2': 'Cristiani is accused of the assassination of six Jesuits.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:186',
#   {'sent1': "Foreign Carmakers Gain in Russia. The likes of Daewoo, Ford, Renault, and more can't produce fast enough.",
#    'sent2': 'European cars sell in Russia.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:187',
#   {'sent1': 'The west has preferred to focus on endangered animals, rather than endangered humans. African elephants are hunted down and stripped of tusks and hidden by poachers. Their numbers in Africa slumped from 1.2m to 600,000 in a decade until CITES - the Convention on International Trade in Endangered Species - banned the trade in ivory.',
#    'sent2': 'An international convention banned trade in ivory.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:188',
#   {'sent1': 'The abode of the Greek gods was on the summit of Mount Olympus, in Thessaly.',
#    'sent2': 'Mount Olympus is in Thessaly.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:189',
#   {'sent1': "Yachtsman Melvyn Percy became so fed up with the standard of service when preparing his boat for the 3000-mile Atlantic crossing that he decided to set up his own company on the Clyde to provide Scots sailors with professional advice and practical assistance. Minerva Rigging, based at Kip Marina just south of Gourock, now employs five full-time staff and is the Scottish agent for Kemp, one of Europe's leading yacht spar and mast manufacturers.",
#    'sent2': 'Melvyn Percy set up Minerva Rigging at Kip Marina.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:19',
#   {'sent1': "Teenage sensation Wayne Rooney powered England into the quarter-finals of Euro 2004 with two goals in Monday's 4-2 defeat of Croatia and they were joined in the last eight by champions France who beat Switzerland 3-1.",
#    'sent2': 'France participates in Euro 2004.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:190',
#   {'sent1': 'The number of Danes opposed to swapping the krone for the euro has increased slightly to 35.3 percent, up from 34.6 percent in April, according to a poll published on Thursday by Danske Bank.',
#    'sent2': 'The introduction of the euro has been opposed.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:191',
#   {'sent1': 'PERSPECTIVE ON BOSNIA; A BALKANS PEACE THAT CANNOT LAST',
#    'sent2': 'Bosnia is located in the former Yugoslavia.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:192',
#   {'sent1': 'Texas Data Recovery is also successful at retrieving lost data from notebooks and laptops, regardless of age, make or model.',
#    'sent2': 'In the event of a disaster you could use Texas Data Recovery and you will have the capability to restore lost data.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:193',
#   {'sent1': 'Nearly five months later on January 24, 1935, the passenger vessel MOHAWK sank after colliding with the Norwegian motorship TALISMAN, and 45 people lost their lives.',
#    'sent2': '100 or more people lost their lives in a ferry sinking.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:195',
#   {'sent1': "The court in Angers handed down sentences ranging from four months suspended to 28 years for, among others, Philppe V., the key accused. The court found that he, along with his son Franck V. and Franck's former spouse, Patricia M., was one the instigators of a sex ring that abused 45 children, mostly in the couple's flat. The abuses of children aged between six months and 12 years took place in a poor and deprived area of the western french town of Angers. Many of the defendants were poor and lived on benefits and some were mentally impaired. About 20 of them admitted to the charges, while others claimed to have never heard of a sex ring.",
#    'sent2': 'Franck V. comes from Angers.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:196',
#   {'sent1': 'The mistaken spelling, Miller explained, was made in a section of her notes unrelated to the interviews with Libby.  Other notes documented 3 interviews with Libby, conducted in the year 2003, that in her NYT column she wrote: June 23) ... Mr. Libby raised the subject of Mr. Wilson\'s wife for the first time. I wrote in my notes, inside parentheses, "Wife works in bureau?" I told Mr. Fitzgerald that I believed this was the first time I had been told that Mr. Wilson\'s wife might work for the C.I.A.',
#    'sent2': 'Judith Miller works for the New York Times.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:197',
#   {'sent1': "Increased storage isn't all Microsoft will be offering its Hotmail users--they can also look forward to free anti-virus protection.",
#    'sent2': "Microsoft won't offer increased storage to its users.",
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:198',
#   {'sent1': 'Capital punishment acts as a deterrent.',
#    'sent2': 'Capital punishment is a deterrent to crime.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:2',
#   {'sent1': 'Yet, we now are discovering that antibiotics are losing their effectiveness against illness. Disease-causing bacteria are mutating faster than we can come up with new antibiotics to fight the new variations.',
#    'sent2': 'Bacteria is winning the war against antibiotics.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:20',
#   {'sent1': "Fujimori charged that on January 26, 1995, Ecuador fired the first shot, an allegation denied by Ecuador's leader, Sixto Duran-Ballen. Predictably, each side blamed the other for starting the 1995 conflict, just as each pointed the finger of guilt to the other for provoking the border war of 1941, when Peru took most of the 120,000 square miles in contention between the two countries.",
#    'sent2': 'President Fujimori was re-elected in 1995.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:200',
#   {'sent1': 'A condition called "social anxiety disorder" this week joined the long list of downers in life - including obesity, impotence, depression and phobia - that Americans once commonly saw as challenges of willpower and character but can now have treated by popping a pill.',
#    'sent2': 'Phobia is a an extreme fear of a particular thing or situation.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:202',
#   {'sent1': 'Italian film-maker, Fellini was awarded an honorary Oscar for lifetime achievement. He died on October 31, 1993.',
#    'sent2': 'An Italian director is awarded an honorary Oscar.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:204',
#   {'sent1': 'Research workers of the German archaeological institute have discovered a mummy in permafrost at excavation work in Mongolia of approximately 2,500 years old.',
#    'sent2': 'Altai ice maiden triggers major dispute.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:205',
#   {'sent1': 'Miller died Thursday night, of congestive heart failure, at his home in Roxbury, Conn., surrounded by his family, his assistant, Julia Bolus, said Friday.',
#    'sent2': 'Miller died Thursday night, of heart failure, surrounded by family members.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:206',
#   {'sent1': "Although he has enough of a support base to be able to create a mass civil disobedience movement, some analysts think that his campaign will be, at best, a thorn in Mr Calderon's side.",
#    'sent2': 'Mr Calderon is able to create a mass civil disobedience movement.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:208',
#   {'sent1': '"Bea Arthur and I first met when we did \'Mame\' together in 1965. She became and has remained \'My Bosom Buddy\' ever since. I am deeply saddened by her passing, but also relieved that she is released from the pain. I spoke to Matt, her son, yesterday and I was aware that her time was imminent. She was a rare and unique performer and a dear, dear friend." Arthur passed away at her home on Saturday at the age of 86. Angela Lansbury is appearing in the current revival of Blithe Spirit which began preview performances on Thursday, February 26, 2009 and had an official opening on Sunday, March 15, 2009 at The Shubert Theatre (225 West 44th Street).',
#    'sent2': 'The actress Angela Lansbury is 86 years old.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:209',
#   {'sent1': 'The girl was found in Drummondville.',
#    'sent2': 'Drummondville contains the girl.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:21',
#   {'sent1': "Hepburn's platinum, diamond and sapphire brooch had been estimated to fetch just $20,000, but sold for $120,000, six times its estimated price.",
#    'sent2': "Hepburn's diamond and sapphire brooch fetched $120,000.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:210',
#   {'sent1': "This is a kind of homework from last year's Halifax Summit. Discussions have taken place on how to rationalize and coordinate the various activities of the international organizations.",
#    'sent2': 'Financial reforms have been proposed at the G7 summit in Halifax.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:212',
#   {'sent1': 'The biggest newspaper in Norway, Verdens Gang, prints a letter to the editor written by Joe Harrington and myself.',
#    'sent2': 'Verdens Gang is a Norwegian newspaper.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:213',
#   {'sent1': "Spirou was created in 1938 by Rob-Vel, who sold the rights to the Dupuis publishing house in early 40's. Other artists like Jije (Joseph Gillain) took care of the feature.",
#    'sent2': 'Spirou was created by Rob-Vel.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:214',
#   {'sent1': 'Zahi Hawass, Egypt\'s pre-eminent archaeologist, revealed the first ancient artifacts which may lead to the discovery of Cleopatra and Marc Antony\'s resting place.  The expedition has found amulets, 22 bronze coins cast with Cleopatra\'s image and her name, a royal statue, an alabaster mask resembling Marc Antony, and a statue bust of Cleopatra. "If you look at the face of Mark Antony, many believed he had this cleft on his chin and that\'s why I thought this could be Mark Antony," said Hawass.  "In my opinion, if this tomb is found, it will be one of the most important discoveries of the 21st century because of the love between Cleopatra and Mark Antony, and because of the sad story of their death. This is the perfect place for them to be hidden," said Hawass.',
#    'sent2': 'Cleopatra and Marc Antony lived in Egypt.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:215',
#   {'sent1': 'Russian Public Television head Vladislav Listyev is shot in the heart by an unknown gunman outside his Moscow home. The attack is linked to opponents of an advertising ban he had proposed for the television channel.',
#    'sent2': 'Vladislav Listyev was murdered in Moscow.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:216',
#   {'sent1': 'Toshiba, with NEC Corp. and Sanyo Electric Co. Ltd., has been promoting a technology called HD DVD while Sony, along with Samsung Electronics Co. Ltd. and Matsushita Electric Industrial Co. Ltd. (maker of Panasonic brand products), has been pushing for Blu-ray.',
#    'sent2': 'Panasonic brand products are produced by Samsung Electronics Co. Ltd.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:217',
#   {'sent1': 'In clashes between Israeli forces and gunmen, one Palestinian was killed and 10 wounded, hospital officials said.',
#    'sent2': 'A Palestinian was killed and other people were wounded.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:220',
#   {'sent1': 'Napkins, invitations and plain old paper cost more than they did a month ago.',
#    'sent2': 'The cost of paper is rising.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:221',
#   {'sent1': "The Daily Telegraph, most prized asset in Lord Conrad Black's crumbling media empire, has been sold to Britain's Barclay twins.",
#    'sent2': 'Daily telegraph is sold.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:222',
#   {'sent1': 'Two Indian diplomats met the Indian prisoner facing death in Pakistan, Sarabjit Singh, on Tuesday at Kot Lakhpat jail in the eastern Pakistani city of Lahore.',
#    'sent2': 'Indian diplomats met an Indian prisoner, on death row, on Tuesday.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:223',
#   {'sent1': "Released in 1995, Tyson returned to boxing, winning the World Boxing Council title in 1996. The same year, however, he lost to Evander Holyfield, and in a 1997 rematch bit Holyfield's ear, for which he was temporarily banned from boxing.",
#    'sent2': "In 1996 Mike Tyson bit Holyfield's ear.",
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:224',
#   {'sent1': "NIH's FY05 budget request of $28.8 billion includes $2 billion for the National Institute of General Medical Sciences, a 3.4-percent increase, and $1.1 billion for the National Center for Research Resources, and a 7.2-percent decrease from FY04 levels.",
#    'sent2': 'A request was reduced to $1.1 billion',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:225',
#   {'sent1': 'Bangladesh, one of the world\'s poorest countries, suffered a devastating drought and famine in 1974, which killed 1.5 million people. While trying to help starving villagers, he met a 21-year-old woman named Sufia Begum, who was burdened by a tiny yet crushing debt, Yunus recalled in his autobiography, "Banker to the Poor."',
# ...
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:56',
#   {'sent1': 'Two British soldiers have been arrested in the southern Iraq city of Basra, sparking clashes outside a police station where they are being held.',
#    'sent2': 'Two British tanks, sent to the police station where the soldiers are being held, were set alight in clashes.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:57',
#   {'sent1': 'Police in the Lower Austrian town of Amstetten have arrested a 73 year old man who is alleged to have kept his daughter, now aged 42, locked in the cellar of his house in Amstetten since 29th August 1984. The man, identified by police as Josef Fritzl, is alleged to have started sexually abusing his daughter, named as Elisabeth Fritzl, when she was eleven years old, and to have subsequently fathered seven children by her. One of the children, one of a set of twins born in 1996, died of neglect shortly after birth and the body was burned by the father.',
#    'sent2': 'Amstetten is located in Austria.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:58',
#   {'sent1': "Microsoft for instance, one of the world's largest software companies, lost more than an estimated 500 million dollars last year because of software theft.",
#    'sent2': 'Microsoft would spend 500 million dollars.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:59',
#   {'sent1': "Primary prevention of Alzheimer's disease is not possible at present.",
#    'sent2': "Alzheimer's disease is treated using drugs.",
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:62',
#   {'sent1': 'The United Kingdom, Turkey, "Old" British commonwealth forces ( New Zealand, Aussies, Canadians, Gurkhas, India), Germany, Poland, Vietnam, some units from USA, Russia, France, China (but only some) Japan would be included but I\'m uncomfortable about using the word respected for Japanese soldiers for obvious reasons.',
#    'sent2': 'The Gurkhas come from Nepal.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:63',
#   {'sent1': 'Ssangyong Motor was taken over by creditors after it collapsed under heavy debts during the 1997-98 Asian financial crisis.',
#    'sent2': 'Asian financial crisis takes over Ssangyong Motor',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:65',
#   {'sent1': 'Asprin, an inexpensive drug helps protect survivors of heart attack and stroke from subsequent heart attacks and death, and even helps reduce the number of deaths that occur within the first hours following a heart attack.',
#    'sent2': 'People experienced adverse effects while taking aspirin.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:67',
#   {'sent1': 'Without a natural greenhouse effect, the temperature of the Earth would be about zero degrees F (-18C) instead of its present 57F (14C).',
#    'sent2': 'Greenhouse effect changes global climate.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:68',
#   {'sent1': "NASA's two Great Observatories, the Hubble Space Telescope and the Chandra X-ray Observatory, have independently provided what could be the best direct evidence yet for the existence of an event horizon, the defining feature of a black hole.",
#    'sent2': 'Hubble discovers black holes.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:69',
#   {'sent1': 'For US pharmaceutical companies, the impending healthcare reforms promise an era of increased cost-containment and pricing controls.',
#    'sent2': 'The US government wants to keep drug prices down.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:7',
#   {'sent1': 'singer and actress Britney Spears, 24, has filled papers in Los Angeles County Superior Court to divorce her husband Kevin Federline, 28. A spokeswoman for the court, Kathy Roberts stated that the papers cited irreconcilable differences" as the reason for the divorce and have, according to the courts, been legally separated as of Monday, November 6, the same day that Spears appeared on Late Night with David Letterman.',
#    'sent2': 'Spears is to divorce from Kevin Federline.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:70',
#   {'sent1': "Giuliana Sgrena was freed from captivity in Iraq today. The Italian journalist was abducted in Baghdad exactly a month ago while  she had been reporting for Il Manifesto. The Islamic Jihad Organisation had taken her hostage on the 4th February with the demand that Italy withdraw all of its troops from Iraq. On February 16, a video was released with a clearly distraught Mrs Sgrena begging for Italy to withdraw from Iraq. However despite the video, the Italian Senate voted to extend its miltary forces' stay in Iraq.",
#    'sent2': 'A female journalist was kidnapped in Iraq.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:71',
#   {'sent1': 'About 33.5 million people live in this massive conurbation. I would guess that 95% of the 5,000 officially foreign-capital firms in Japan are based in Tokyo.',
#    'sent2': 'About 33.5 miilion people live in Tokyo.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:72',
#   {'sent1': 'Tropical Storm Irene on August 11, 2005 at 16:15 UTC. Tropical Storm Irene will increase in strength over the next several days, possibly developing into   a hurricane that will hit the east coast of the United States, said the National Hurricane Center of Miami, Florida in a report today.  Irene was located approximately 975 kilometers south-southeast of Bermuda at 16:00 UTC today. Forecasters say that the storm is now moving in a west-  northwest direction with top sustained winds of 40 miles per hour.',
#    'sent2': 'A storm called Irene is going to approach the east coast of the US.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:73',
#   {'sent1': 'One of the dead was a child, passing by with his parents, said Iqrar Abbasi, a doctor at Civil Hospital Karachi.',
#    'sent2': 'A doctor was killed by his parents.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:74',
#   {'sent1': 'The Cyrillic alphabet is an alphabet used for several East and South Slavic languages; (Belarusian, Bulgarian, Macedonian, Russian, Rusyn, Serbian, and Ukrainian) and many other languages of the former Soviet Union, Asia and Eastern Europe. It has also been used for other languages in the past. Not all letters in the Cyrillic alphabet are used in every language which is written with it.',
#    'sent2': 'Cyrillic is an alphabet used for certain Slavic languages, such as Russian.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:75',
#   {'sent1': 'In November 1990, the president announced that opposition political parties would be permitted to organize in 1991. Several new parties emerged, including the Democratic Republican Movement (MDR), the Liberal Party (LP), the Democratic and Socialist Party (PSD), and the Coalition for the Defense of the Republic (CDR).',
#    'sent2': 'Several new political parties emerged.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:76',
#   {'sent1': 'A closely divided U.S. Supreme Court said on Thursday its 2002 ruling that juries and not judges must impose a death sentence applies only to future cases, a decision that may affect more than 100 death row inmates.',
#    'sent2': 'The Supreme Court decided that only judges can impose the death sentence.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:77',
#   {'sent1': 'The Disneyland of Europe is located 20 miles east of Paris. Euro Disney is a huge complex with hotels, restaurants, shops and a nearby golf course apart from the actual theme park. It provides a much better experience than its American cousin thanks to the marvels of modern engineering.',
#    'sent2': 'Euro-Disney is an Entertainment Park.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:78',
#   {'sent1': 'The chaotic situation unleashed in Bogota last night, with the assasination of Justice Carlos Valencia, began on 28 July in Medellin, when motorized paid assasins murdered third public order Judge Maria Elena Diaz.',
#    'sent2': 'Justice Carlos Valencia was killed in Medellin.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:79',
#   {'sent1': "The medical student accused of murdering an erotic masseuse he met on Craigslist is drowning in more than $100,000 in student loan debt and is so broke he can't afford to pay an attorney, according to court papers. Philip Markoff, a 23-year-old suspended Boston University medical school student, owes $130,000 in student loans and does not get money from his parents, leaving him to lean on a taxpayer-funded attorney for his defense, according to a court document in Boston Municipal Court that labels him indigent. Markoff graduated from the State University of New York-Albany and was a second-year medical student at BU.",
#    'sent2': 'The medical student Philip Markoff was engaged.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:8',
#   {'sent1': 'Following the successful bid to bring the 2010 Ryder Cup to Wales, the Wales Tourist Board has wasted little time in commissioning work to ensure that the benefits accruing from the event are felt throughout the country.',
#    'sent2': 'Wales to host 2010 Ryder Cup.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:80',
#   {'sent1': 'The west has preferred to focus on endangered animals, rather than endangered humans. African elephants are hunted down and stripped of tusks and hidden by poachers. Their numbers in Africa slumped from 1.2m to 600,000 in a decade until CITES - the Convention on International Trade in Endangered Species - banned the trade in ivory.',
#    'sent2': 'African elephants are endangered by ivory poachers.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:81',
#   {'sent1': 'The extension of the effective period of marketing exclusivity for drugs is designed to give pharmaceutical companies a fair return.',
#    'sent2': 'Prospective drugs must have long market life after regulatory approval in order to be developed.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:84',
#   {'sent1': 'The official visit of the Argentine minister marks a further step in the normalisation of UK-Argentine relations.',
#    'sent2': 'Relations between Argentina and Great Britain are growing more cooperative.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:85',
#   {'sent1': 'It is hoped that women, who constitute more than half of the population, will vote for other women and ensure that their issues are represented in parliament.',
#    'sent2': 'Women are poorly represented in parliament.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:87',
#   {'sent1': 'The job gains mean that  President Bush can celebrate - albeit by a very fine margin - a net growth in jobs in the US economy in his first term in office.',
#    'sent2': "More jobs were created during President Bush's first term.",
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:88',
#   {'sent1': 'The Federal Bureau of Investigation started an independent probe of the circumstances shortly after the White House made plain that President Bill Clinton considered industrial espionage a particular threat to US economic interests.',
#    'sent2': 'A US probe of the investigation started at the instigation of the Commerce Department.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:89',
#   {'sent1': 'Researchers at the Harvard School of Public Health say that people who drink coffee may be doing a lot more than keeping themselves awake - this kind of consumption apparently also can help reduce the risk of diseases.',
#    'sent2': 'Coffee drinking has health benefits.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:9',
#   {'sent1': 'Steve Jobs was attacked by Sculley and other Apple executives for not delivering enough hot new products and resigned from the company a few weeks later.',
#    'sent2': 'Steve Jobs worked for Apple.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:90',
#   {'sent1': 'A top aide to Ms. Bhutto, Senator Latif Khosa, says that on the day of her assassination, Ms. Bhutto planned to give two visiting U.S. lawmakers a thick dossier outlining numerous instances of government pre-poll rigging involving voter registration as well as intimidation of PPP supporters. "Everything was recorded in that, with all proofs that we have had, and with the independent reports of the foreign monitors who were also operating. Their reports also supported our allegations as to being substantial and as being true. So they were all recorded, but unfortunately she could not present the report because she was assassinated before she could do that," said Khosa.',
#    'sent2': 'Latif Khosa was in a relationship with Ms. Bhutto.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:91',
#   {'sent1': 'South America - The President of Colombia Alvaro Uribe is scheduled to meet the President of Venezuela Hugo Chávez Thursday. Apparently the crisis between Venezuela and Colombia is almost solved. The crisis began with the imprisonment of the alleged FARC member Rodrigo Granda by Colombian forces on December 13, 2004. Venezuela accused Colombian of invading Venezuelan territory. Colombia accused Venezuela of harboring FARC terrorists. The President of Cuba, Fidel Castro, intervened in the crisis and talked to Chavez and Uribe.',
#    'sent2': 'Alvaro Uribe is the current President of Colombia.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:92',
#   {'sent1': 'The town is also home to the Dalai Lama and to more than 10,000 Tibetans living in exile.',
#    'sent2': 'The Dalai Lama has been living in exile since 10,000.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:93',
#   {'sent1': 'Adela Lupse was born in 1988 to a miner\'s family in the village of Poiana, Bihor in Transylvania, Romania. A member of Romania\'s first post-Ceausescu generation, she grasped the power of television at a young age: "I think television is the most interesting phenomenon that the modern day has given us....for my type of personality, I find it impressive, the power that television has worldwide....We dress like the people that television promotes. We want to look like the celebrities that television launches."',
#    'sent2': 'Bihor is situated in Romania.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:94',
#   {'sent1': 'Merrill Lynch & Co. and Smith Barney, now a unit of Citigroup, in 1998 settled discrimination cases involving hundreds of female employees.',
#    'sent2': 'Merrill Lynch & Co. and Smith Barney are now a unit of Citigroup.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:95',
#   {'sent1': 'La Paz, 30 May 89 - La Paz Department Police authorities have disclosed that investigations into the murder of two young U.S. citizens are being conducted by a specialized group summoned specially to clarify this crime.',
#    'sent2': 'Two young U.S. citizens were killed on 30 May 89.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:96',
#   {'sent1': 'I asked myself how to understand the \'Twilight\'s success. And I have come to the idea that when you really believe in something, sooner or later it will become real. So, I guess this is what happened with Robert Pattinson. Last year he was just an unknown actor who\'s biggest role was in a pair of "Harry Potter" movies. Now, not only that Twilight is competing with \'Harry Potter\', but Robert Pattinson is one of the most famous young actors who sucked $373.4 million from global box offices. So the movie about a vampire boy who falls in love with a normal girl, begun a real hysteria. And Pattinson has a lot to do with it!.',
#    'sent2': 'Robert Pattinson is a vampire.',
#    'label': 'not_entailment'}),
#  ('RTE/dev.tsv:98',
#   {'sent1': 'The Supreme Court said today states may bar the removal of life-sustaining treatment from comatose patients who have not made or cannot make their desires known.',
#    'sent2': 'There is a Supreme Court decision about the removal of life-support.',
#    'label': 'entailment'}),
#  ('RTE/dev.tsv:99',
#   {'sent1': 'The Massachusetts Supreme Judicial Court has cleared the way for lesbian and gay couples in the state to marry, ruling that government attorneys "failed to identify any constitutionally adequate reason" to deny them the right.',
#    'sent2': 'U.S. Supreme Court in favor of same-sex marriage',
#    'label': 'entailment'})]

# %% [markdown]
# ### Eval on slices with Uncased model

# %%
from metal.mmtl.debugging.utils import load_data_and_model, create_dataframe

# Load model and data
model_path = '/dfs/scratch0/mccreery/mmtl/logs/ST_bertlarge/COLA/logdir/2019_02_25/COLA_21_56_02/best_model.pth'
task_name = 'COLA'
split = 'dev'
bert_model = "bert-large-uncased"
model, dl = load_data_and_model(model_path, [task_name], split, bert_model=bert_model)
# Out:
# Could not find kwarg "generate_uids" in destination dict.
# Using random seed: 895115
# Loading COLA Dataset
# HBox(children=(IntProgress(value=0, max=1042), HTML(value='')))

# %%
filepath = f'{task_name}_{bert_model}_{split}_error_analysis.tsv'

# Create DataFrame of Raw Data, Predictions, and Labels
print('Creating dataframe')
df_uncased = create_dataframe(task_name, model, dl, bert_model=bert_model)
print('Created dataframe')

# Save (and reload) DataFrame
save_dataframe(df_uncased, filepath)
# Out:
# Creating dataframe
# 1042it [00:29, 34.88it/s]
# Created dataframe
# Saved dataframe to:  COLA_bert-large-uncased_dev_error_analysis.tsv

# %%
df_uncased = load_dataframe(filepath)

# %%
def df_for_uids(df, uids):
    mask = df['uid'].apply(lambda x: x in uids)
    return df[mask]

# %%
slice_uids = tagger.get_uids(slice_name)
df_uncased_in_slice = df_for_uids(df_uncased, slice_uids)

# %%
df_uncased_in_slice[df_uncased_in_slice['is_wrong']].head(20)
# Out:
#      Unnamed: 0  \
# 74   74
# 88   88
# 122  122
# 123  123
# 198  198
# 413  413
# 467  467
# 588  588
# 653  653
# 863  863
#
#                                                                                                                    sentence1  \
# 74    the mayor regarded as being absurd the proposal to build a sidewalk from dartmouth to smith .
# 88    i live at the place where route 150 crosses the hudson river and my dad lives at it too .
# 122   no writer , and no playwright , meets in vienna .
# 123   no writer , nor any playwright , meets in vienna .
# 198   cynthia chewed .
# 413   the idea dismay ##ed the prime minister that the dome was dull .
# 467   only churchill remembered churchill giving the blood , sweat and tears speech .
# 588   the ta ' s have been arguing about whether some student or other should pass , but i can ' t now remember which one .
# 653   harry told sue that albania is a lovely place for a vacation , and tom .
# 863   us like them .
#
#      sentence2     score  label               uid  pred  is_wrong
# 74  NaN         0.999036  0      CoLA/dev.tsv:76   1     True
# 88  NaN         0.997461  0      CoLA/dev.tsv:90   1     True
# 122 NaN         0.997668  0      CoLA/dev.tsv:124  1     True
# 123 NaN         0.997774  0      CoLA/dev.tsv:125  1     True
# 198 NaN         0.666183  0      CoLA/dev.tsv:200  1     True
# 413 NaN         0.038873  1      CoLA/dev.tsv:415  0     True
# 467 NaN         0.998912  0      CoLA/dev.tsv:469  1     True
# 588 NaN         0.994458  0      CoLA/dev.tsv:590  1     True
# 653 NaN         0.040067  1      CoLA/dev.tsv:655  0     True
# 863 NaN         0.997570  0      CoLA/dev.tsv:865  1     True

# %%
print ("Error rate:", len(df_uncased_in_slice[df_uncased_in_slice['is_wrong']])
                                              / len(df_uncased_in_slice))
# Out:
# Error rate: 0.16393442622950818

# %% [markdown]
# ## Eval on Slice with Cased Model

# %%
from metal.mmtl.debugging.utils import load_data_and_model, create_dataframe

# Load model and data
model_path = '/dfs/scratch0/mccreery/mmtl/logs/ST_bertlarge/COLA_cased/2/logdir/2019_03_05/COLA_00_50_04/best_model.pth'
task_name = 'COLA'
split = 'dev'
bert_model = "bert-large-cased"
model,dl = load_data_and_model(model_path, [task_name], split, bert_model=bert_model)
# Out:
# Could not find kwarg "generate_uids" in destination dict.
# Using random seed: 155826
# Loading COLA Dataset
# HBox(children=(IntProgress(value=0, max=1042), HTML(value='')))

# %%
filepath = f'{task_name}_{bert_model}_{split}_error_analysis.tsv'

# Create DataFrame of Raw Data, Predictions, and Labels
print('Creating dataframe')
df_cased = create_dataframe(task_name, model, dl, bert_model=bert_model)
print('Created dataframe')

# Save (and reload) DataFrame
save_dataframe(df_cased, filepath)
# Out:
# Creating dataframe
# 1042it [00:29, 35.71it/s]
# Created dataframe
# Saved dataframe to:  COLA_bert-large-cased_dev_error_analysis.tsv

# %%
df_cased = load_dataframe(filepath)

# %%
df_cased_in_slice = df_for_uids(df_cased, slice_uids)

# %%
df_cased_in_slice[df_cased_in_slice['is_wrong']].head()
# Out:
#      Unnamed: 0  \
# 74   74
# 88   88
# 122  122
# 198  198
# 467  467
#
#                                                                                            sentence1  \
# 74    The mayor regarded as being absurd the proposal to build a sidewalk from Dartmouth to Smith .
# 88    I live at the place where Route 150 crosses the Hudson River and my dad lives at it too .
# 122   No writer , and no playwright , meets in Vienna .
# 198   Cynthia chewed .
# 467   Only Churchill remembered Churchill giving the Blood , Sweat and Tears speech .
#
#      sentence2     score  label               uid  pred  is_wrong
# 74  NaN         0.999908  0      CoLA/dev.tsv:76   1     True
# 88  NaN         0.999800  0      CoLA/dev.tsv:90   1     True
# 122 NaN         0.999385  0      CoLA/dev.tsv:124  1     True
# 198 NaN         0.999898  0      CoLA/dev.tsv:200  1     True
# 467 NaN         0.999896  0      CoLA/dev.tsv:469  1     True

# %%
print ("Error rate:", len(df_cased_in_slice[df_cased_in_slice['is_wrong']])
                                              / len(df_cased_in_slice))
# Out:
# Error rate: 0.11475409836065574

# %% [markdown]
# ## Error analysis on differences in predictions!

# %%
df_uncased.head()
# Out:
#    Unnamed: 0                                                 sentence1  \
# 0  0            the weights made the rope stretch over the pull ##ey .
# 1  1            the mechanical doll wr ##ig ##gled itself loose .
# 2  2            if you had eaten more , you would want less .
# 3  3            as you eat the most , you want the least .
# 4  4            the more you would want , the less you would eat .
#
#    sentence2     score  label             uid  pred  is_wrong
# 0 NaN         0.998119  1      CoLA/dev.tsv:2  1     False
# 1 NaN         0.997867  1      CoLA/dev.tsv:3  1     False
# 2 NaN         0.999306  1      CoLA/dev.tsv:4  1     False
# 3 NaN         0.976777  0      CoLA/dev.tsv:5  1     True
# 4 NaN         0.998284  0      CoLA/dev.tsv:6  1     True

# %%
df_cased.head()
# Out:
#    Unnamed: 0                                                 sentence1  \
# 0  0            The weights made the rope stretch over the pull ##ey .
# 1  1            The mechanical doll w ##rig ##gled itself loose .
# 2  2            If you had eaten more , you would want less .
# 3  3            As you eat the most , you want the least .
# 4  4            The more you would want , the less you would eat .
#
#    sentence2     score  label             uid  pred  is_wrong
# 0 NaN         0.999909  1      CoLA/dev.tsv:2  1     False
# 1 NaN         0.000127  1      CoLA/dev.tsv:3  0     True
# 2 NaN         0.999914  1      CoLA/dev.tsv:4  1     False
# 3 NaN         0.999184  0      CoLA/dev.tsv:5  1     True
# 4 NaN         0.999899  0      CoLA/dev.tsv:6  1     True

# %%
# retrieve list uids corresponding to INCORRECT ex in UNCASED
incorrect_uncased_uids = df_uncased_in_slice[df_uncased_in_slice['is_wrong']]['uid'].to_list()

incorrect_cased_uids = df_cased_in_slice[df_cased_in_slice['is_wrong']]['uid'].to_list()

# retrieved list of uids corresponding to CORRECT ex in CASED model
correct_cased_uids = df_cased_in_slice[~df_cased_in_slice['is_wrong']]['uid'].to_list()

# %% [markdown]
# ### Which examples were "corrected" by the casing model?

# %%
corrected_by_casing_uids = set(incorrect_uncased_uids).intersection(set(correct_cased_uids))
df_for_uids(df_uncased, corrected_by_casing_uids).head(20)
# Out:
#      Unnamed: 0  \
# 123  123
# 413  413
# 863  863
#
#                                                               sentence1  \
# 123   no writer , nor any playwright , meets in vienna .
# 413   the idea dismay ##ed the prime minister that the dome was dull .
# 863   us like them .
#
#      sentence2     score  label               uid  pred  is_wrong
# 123 NaN         0.997774  0      CoLA/dev.tsv:125  1     True
# 413 NaN         0.038873  1      CoLA/dev.tsv:415  0     True
# 863 NaN         0.997570  0      CoLA/dev.tsv:865  1     True

# %%
df_for_uids(df_cased, corrected_by_casing_uids).head(20)
# Out:
#      Unnamed: 0  \
# 123  123
# 413  413
# 863  863
#
#                                                               sentence1  \
# 123   No writer , nor any playwright , meets in Vienna .
# 413   The idea dismay ##ed the Prime Minister that the Dome was dull .
# 863   Us like them .
#
#      sentence2     score  label               uid  pred  is_wrong
# 123 NaN         0.035777  0      CoLA/dev.tsv:125  0     False
# 413 NaN         0.999859  1      CoLA/dev.tsv:415  1     False
# 863 NaN         0.000130  0      CoLA/dev.tsv:865  0     False

# %% [markdown]
# ### Which examples are "still incorrect" with the casing model?

# %%
still_incorrect_uids = set(incorrect_uncased_uids).intersection(set(incorrect_cased_uids))
df_for_uids(df_cased, still_incorrect_uids).head(20)
# Out:
#      Unnamed: 0  \
# 74   74
# 88   88
# 122  122
# 198  198
# 467  467
# 588  588
# 653  653
#
#                                                                                                                       sentence1  \
# 74    The mayor regarded as being absurd the proposal to build a sidewalk from Dartmouth to Smith .
# 88    I live at the place where Route 150 crosses the Hudson River and my dad lives at it too .
# 122   No writer , and no playwright , meets in Vienna .
# 198   Cynthia chewed .
# 467   Only Churchill remembered Churchill giving the Blood , Sweat and Tears speech .
# 588   The T ##A ' s have been arguing about whether some student or other should pass , but I can ' t now remember which one .
# 653   Harry told Sue that Albania is a lovely place for a vacation , and Tom .
#
#      sentence2     score  label               uid  pred  is_wrong
# 74  NaN         0.999908  0      CoLA/dev.tsv:76   1     True
# 88  NaN         0.999800  0      CoLA/dev.tsv:90   1     True
# 122 NaN         0.999385  0      CoLA/dev.tsv:124  1     True
# 198 NaN         0.999898  0      CoLA/dev.tsv:200  1     True
# 467 NaN         0.999896  0      CoLA/dev.tsv:469  1     True
# 588 NaN         0.999845  0      CoLA/dev.tsv:590  1     True
# 653 NaN         0.000287  1      CoLA/dev.tsv:655  0     True
