# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import os
import torch

# %%
from metal.mmtl.debugging.utils import load_data_and_model, create_dataframe
model_path = '/dfs/scratch0/chami/metal/logs/2019_02_20/COLA_23_41_22/'
task_name = 'COLA'
split = 'test'
model,dl = load_data_and_model(model_path,task_name,split)
# Out:
# Could not find kwarg "generate_uids" in destination dict.
# Using random seed: 507565.
# Loading COLA Dataset
# HBox(children=(IntProgress(value=0, max=1063), HTML(value='')))

# %%
COLA_test_uids = dl.dataset.uids
COLA_test_uids
# Out:
# ['CoLA/test.tsv:2',
#  'CoLA/test.tsv:3',
#  'CoLA/test.tsv:4',
#  'CoLA/test.tsv:5',
#  'CoLA/test.tsv:6',
#  'CoLA/test.tsv:7',
#  'CoLA/test.tsv:8',
#  'CoLA/test.tsv:9',
#  'CoLA/test.tsv:10',
#  'CoLA/test.tsv:11',
#  'CoLA/test.tsv:12',
#  'CoLA/test.tsv:13',
#  'CoLA/test.tsv:14',
#  'CoLA/test.tsv:15',
#  'CoLA/test.tsv:16',
#  'CoLA/test.tsv:17',
#  'CoLA/test.tsv:18',
#  'CoLA/test.tsv:19',
#  'CoLA/test.tsv:20',
#  'CoLA/test.tsv:21',
#  'CoLA/test.tsv:22',
#  'CoLA/test.tsv:23',
#  'CoLA/test.tsv:24',
#  'CoLA/test.tsv:25',
#  'CoLA/test.tsv:26',
#  'CoLA/test.tsv:27',
#  'CoLA/test.tsv:28',
#  'CoLA/test.tsv:29',
#  'CoLA/test.tsv:30',
#  'CoLA/test.tsv:31',
#  'CoLA/test.tsv:32',
#  'CoLA/test.tsv:33',
#  'CoLA/test.tsv:34',
#  'CoLA/test.tsv:35',
#  'CoLA/test.tsv:36',
#  'CoLA/test.tsv:37',
#  'CoLA/test.tsv:38',
#  'CoLA/test.tsv:39',
#  'CoLA/test.tsv:40',
#  'CoLA/test.tsv:41',
#  'CoLA/test.tsv:42',
#  'CoLA/test.tsv:43',
#  'CoLA/test.tsv:44',
#  'CoLA/test.tsv:45',
#  'CoLA/test.tsv:46',
#  'CoLA/test.tsv:47',
#  'CoLA/test.tsv:48',
#  'CoLA/test.tsv:49',
#  'CoLA/test.tsv:50',
#  'CoLA/test.tsv:51',
#  'CoLA/test.tsv:52',
#  'CoLA/test.tsv:53',
#  'CoLA/test.tsv:54',
#  'CoLA/test.tsv:55',
#  'CoLA/test.tsv:56',
#  'CoLA/test.tsv:57',
#  'CoLA/test.tsv:58',
#  'CoLA/test.tsv:59',
#  'CoLA/test.tsv:60',
#  'CoLA/test.tsv:61',
#  'CoLA/test.tsv:62',
#  'CoLA/test.tsv:63',
#  'CoLA/test.tsv:64',
#  'CoLA/test.tsv:65',
#  'CoLA/test.tsv:66',
#  'CoLA/test.tsv:67',
#  'CoLA/test.tsv:68',
#  'CoLA/test.tsv:69',
#  'CoLA/test.tsv:70',
#  'CoLA/test.tsv:71',
#  'CoLA/test.tsv:72',
#  'CoLA/test.tsv:73',
#  'CoLA/test.tsv:74',
#  'CoLA/test.tsv:75',
#  'CoLA/test.tsv:76',
#  'CoLA/test.tsv:77',
#  'CoLA/test.tsv:78',
#  'CoLA/test.tsv:79',
#  'CoLA/test.tsv:80',
#  'CoLA/test.tsv:81',
#  'CoLA/test.tsv:82',
#  'CoLA/test.tsv:83',
#  'CoLA/test.tsv:84',
#  'CoLA/test.tsv:85',
#  'CoLA/test.tsv:86',
#  'CoLA/test.tsv:87',
#  'CoLA/test.tsv:88',
#  'CoLA/test.tsv:89',
#  'CoLA/test.tsv:90',
#  'CoLA/test.tsv:91',
#  'CoLA/test.tsv:92',
#  'CoLA/test.tsv:93',
#  'CoLA/test.tsv:94',
#  'CoLA/test.tsv:95',
#  'CoLA/test.tsv:96',
#  'CoLA/test.tsv:97',
#  'CoLA/test.tsv:98',
#  'CoLA/test.tsv:99',
#  'CoLA/test.tsv:100',
#  'CoLA/test.tsv:101',
#  'CoLA/test.tsv:102',
#  'CoLA/test.tsv:103',
#  'CoLA/test.tsv:104',
#  'CoLA/test.tsv:105',
#  'CoLA/test.tsv:106',
#  'CoLA/test.tsv:107',
#  'CoLA/test.tsv:108',
#  'CoLA/test.tsv:109',
#  'CoLA/test.tsv:110',
#  'CoLA/test.tsv:111',
#  'CoLA/test.tsv:112',
#  'CoLA/test.tsv:113',
#  'CoLA/test.tsv:114',
#  'CoLA/test.tsv:115',
#  'CoLA/test.tsv:116',
#  'CoLA/test.tsv:117',
#  'CoLA/test.tsv:118',
#  'CoLA/test.tsv:119',
#  'CoLA/test.tsv:120',
#  'CoLA/test.tsv:121',
#  'CoLA/test.tsv:122',
#  'CoLA/test.tsv:123',
#  'CoLA/test.tsv:124',
#  'CoLA/test.tsv:125',
#  'CoLA/test.tsv:126',
#  'CoLA/test.tsv:127',
#  'CoLA/test.tsv:128',
#  'CoLA/test.tsv:129',
#  'CoLA/test.tsv:130',
#  'CoLA/test.tsv:131',
#  'CoLA/test.tsv:132',
#  'CoLA/test.tsv:133',
#  'CoLA/test.tsv:134',
#  'CoLA/test.tsv:135',
#  'CoLA/test.tsv:136',
#  'CoLA/test.tsv:137',
#  'CoLA/test.tsv:138',
#  'CoLA/test.tsv:139',
#  'CoLA/test.tsv:140',
#  'CoLA/test.tsv:141',
#  'CoLA/test.tsv:142',
#  'CoLA/test.tsv:143',
#  'CoLA/test.tsv:144',
#  'CoLA/test.tsv:145',
#  'CoLA/test.tsv:146',
#  'CoLA/test.tsv:147',
#  'CoLA/test.tsv:148',
#  'CoLA/test.tsv:149',
#  'CoLA/test.tsv:150',
#  'CoLA/test.tsv:151',
#  'CoLA/test.tsv:152',
#  'CoLA/test.tsv:153',
#  'CoLA/test.tsv:154',
#  'CoLA/test.tsv:155',
#  'CoLA/test.tsv:156',
#  'CoLA/test.tsv:157',
#  'CoLA/test.tsv:158',
#  'CoLA/test.tsv:159',
#  'CoLA/test.tsv:160',
#  'CoLA/test.tsv:161',
#  'CoLA/test.tsv:162',
#  'CoLA/test.tsv:163',
#  'CoLA/test.tsv:164',
#  'CoLA/test.tsv:165',
#  'CoLA/test.tsv:166',
#  'CoLA/test.tsv:167',
#  'CoLA/test.tsv:168',
#  'CoLA/test.tsv:169',
#  'CoLA/test.tsv:170',
#  'CoLA/test.tsv:171',
#  'CoLA/test.tsv:172',
#  'CoLA/test.tsv:173',
#  'CoLA/test.tsv:174',
#  'CoLA/test.tsv:175',
#  'CoLA/test.tsv:176',
#  'CoLA/test.tsv:177',
#  'CoLA/test.tsv:178',
#  'CoLA/test.tsv:179',
#  'CoLA/test.tsv:180',
#  'CoLA/test.tsv:181',
#  'CoLA/test.tsv:182',
#  'CoLA/test.tsv:183',
#  'CoLA/test.tsv:184',
#  'CoLA/test.tsv:185',
#  'CoLA/test.tsv:186',
#  'CoLA/test.tsv:187',
#  'CoLA/test.tsv:188',
#  'CoLA/test.tsv:189',
#  'CoLA/test.tsv:190',
#  'CoLA/test.tsv:191',
#  'CoLA/test.tsv:192',
#  'CoLA/test.tsv:193',
#  'CoLA/test.tsv:194',
#  'CoLA/test.tsv:195',
#  'CoLA/test.tsv:196',
#  'CoLA/test.tsv:197',
#  'CoLA/test.tsv:198',
#  'CoLA/test.tsv:199',
#  'CoLA/test.tsv:200',
#  'CoLA/test.tsv:201',
#  'CoLA/test.tsv:202',
#  'CoLA/test.tsv:203',
#  'CoLA/test.tsv:204',
#  'CoLA/test.tsv:205',
#  'CoLA/test.tsv:206',
#  'CoLA/test.tsv:207',
#  'CoLA/test.tsv:208',
#  'CoLA/test.tsv:209',
#  'CoLA/test.tsv:210',
#  'CoLA/test.tsv:211',
#  'CoLA/test.tsv:212',
#  'CoLA/test.tsv:213',
#  'CoLA/test.tsv:214',
#  'CoLA/test.tsv:215',
#  'CoLA/test.tsv:216',
#  'CoLA/test.tsv:217',
#  'CoLA/test.tsv:218',
#  'CoLA/test.tsv:219',
#  'CoLA/test.tsv:220',
#  'CoLA/test.tsv:221',
#  'CoLA/test.tsv:222',
#  'CoLA/test.tsv:223',
#  'CoLA/test.tsv:224',
#  'CoLA/test.tsv:225',
#  'CoLA/test.tsv:226',
#  'CoLA/test.tsv:227',
#  'CoLA/test.tsv:228',
#  'CoLA/test.tsv:229',
#  'CoLA/test.tsv:230',
#  'CoLA/test.tsv:231',
#  'CoLA/test.tsv:232',
#  'CoLA/test.tsv:233',
#  'CoLA/test.tsv:234',
#  'CoLA/test.tsv:235',
#  'CoLA/test.tsv:236',
#  'CoLA/test.tsv:237',
#  'CoLA/test.tsv:238',
#  'CoLA/test.tsv:239',
#  'CoLA/test.tsv:240',
#  'CoLA/test.tsv:241',
#  'CoLA/test.tsv:242',
#  'CoLA/test.tsv:243',
#  'CoLA/test.tsv:244',
#  'CoLA/test.tsv:245',
#  'CoLA/test.tsv:246',
#  'CoLA/test.tsv:247',
#  'CoLA/test.tsv:248',
#  'CoLA/test.tsv:249',
#  'CoLA/test.tsv:250',
#  'CoLA/test.tsv:251',
#  'CoLA/test.tsv:252',
#  'CoLA/test.tsv:253',
#  'CoLA/test.tsv:254',
#  'CoLA/test.tsv:255',
#  'CoLA/test.tsv:256',
#  'CoLA/test.tsv:257',
#  'CoLA/test.tsv:258',
#  'CoLA/test.tsv:259',
#  'CoLA/test.tsv:260',
#  'CoLA/test.tsv:261',
#  'CoLA/test.tsv:262',
#  'CoLA/test.tsv:263',
#  'CoLA/test.tsv:264',
#  'CoLA/test.tsv:265',
#  'CoLA/test.tsv:266',
#  'CoLA/test.tsv:267',
#  'CoLA/test.tsv:268',
#  'CoLA/test.tsv:269',
#  'CoLA/test.tsv:270',
#  'CoLA/test.tsv:271',
#  'CoLA/test.tsv:272',
#  'CoLA/test.tsv:273',
#  'CoLA/test.tsv:274',
#  'CoLA/test.tsv:275',
#  'CoLA/test.tsv:276',
#  'CoLA/test.tsv:277',
#  'CoLA/test.tsv:278',
#  'CoLA/test.tsv:279',
#  'CoLA/test.tsv:280',
#  'CoLA/test.tsv:281',
#  'CoLA/test.tsv:282',
#  'CoLA/test.tsv:283',
#  'CoLA/test.tsv:284',
#  'CoLA/test.tsv:285',
#  'CoLA/test.tsv:286',
#  'CoLA/test.tsv:287',
#  'CoLA/test.tsv:288',
#  'CoLA/test.tsv:289',
#  'CoLA/test.tsv:290',
#  'CoLA/test.tsv:291',
#  'CoLA/test.tsv:292',
#  'CoLA/test.tsv:293',
#  'CoLA/test.tsv:294',
#  'CoLA/test.tsv:295',
#  'CoLA/test.tsv:296',
#  'CoLA/test.tsv:297',
#  'CoLA/test.tsv:298',
#  'CoLA/test.tsv:299',
#  'CoLA/test.tsv:300',
#  'CoLA/test.tsv:301',
#  'CoLA/test.tsv:302',
#  'CoLA/test.tsv:303',
#  'CoLA/test.tsv:304',
#  'CoLA/test.tsv:305',
#  'CoLA/test.tsv:306',
#  'CoLA/test.tsv:307',
#  'CoLA/test.tsv:308',
#  'CoLA/test.tsv:309',
#  'CoLA/test.tsv:310',
#  'CoLA/test.tsv:311',
#  'CoLA/test.tsv:312',
#  'CoLA/test.tsv:313',
#  'CoLA/test.tsv:314',
#  'CoLA/test.tsv:315',
#  'CoLA/test.tsv:316',
#  'CoLA/test.tsv:317',
#  'CoLA/test.tsv:318',
#  'CoLA/test.tsv:319',
#  'CoLA/test.tsv:320',
#  'CoLA/test.tsv:321',
#  'CoLA/test.tsv:322',
#  'CoLA/test.tsv:323',
#  'CoLA/test.tsv:324',
#  'CoLA/test.tsv:325',
#  'CoLA/test.tsv:326',
#  'CoLA/test.tsv:327',
#  'CoLA/test.tsv:328',
#  'CoLA/test.tsv:329',
#  'CoLA/test.tsv:330',
#  'CoLA/test.tsv:331',
#  'CoLA/test.tsv:332',
#  'CoLA/test.tsv:333',
#  'CoLA/test.tsv:334',
#  'CoLA/test.tsv:335',
#  'CoLA/test.tsv:336',
#  'CoLA/test.tsv:337',
#  'CoLA/test.tsv:338',
#  'CoLA/test.tsv:339',
#  'CoLA/test.tsv:340',
#  'CoLA/test.tsv:341',
#  'CoLA/test.tsv:342',
#  'CoLA/test.tsv:343',
#  'CoLA/test.tsv:344',
#  'CoLA/test.tsv:345',
#  'CoLA/test.tsv:346',
#  'CoLA/test.tsv:347',
#  'CoLA/test.tsv:348',
#  'CoLA/test.tsv:349',
#  'CoLA/test.tsv:350',
#  'CoLA/test.tsv:351',
#  'CoLA/test.tsv:352',
#  'CoLA/test.tsv:353',
#  'CoLA/test.tsv:354',
#  'CoLA/test.tsv:355',
#  'CoLA/test.tsv:356',
#  'CoLA/test.tsv:357',
#  'CoLA/test.tsv:358',
#  'CoLA/test.tsv:359',
#  'CoLA/test.tsv:360',
#  'CoLA/test.tsv:361',
#  'CoLA/test.tsv:362',
#  'CoLA/test.tsv:363',
#  'CoLA/test.tsv:364',
#  'CoLA/test.tsv:365',
#  'CoLA/test.tsv:366',
#  'CoLA/test.tsv:367',
#  'CoLA/test.tsv:368',
#  'CoLA/test.tsv:369',
#  'CoLA/test.tsv:370',
#  'CoLA/test.tsv:371',
#  'CoLA/test.tsv:372',
#  'CoLA/test.tsv:373',
#  'CoLA/test.tsv:374',
#  'CoLA/test.tsv:375',
#  'CoLA/test.tsv:376',
#  'CoLA/test.tsv:377',
#  'CoLA/test.tsv:378',
#  'CoLA/test.tsv:379',
#  'CoLA/test.tsv:380',
#  'CoLA/test.tsv:381',
#  'CoLA/test.tsv:382',
#  'CoLA/test.tsv:383',
#  'CoLA/test.tsv:384',
#  'CoLA/test.tsv:385',
#  'CoLA/test.tsv:386',
#  'CoLA/test.tsv:387',
#  'CoLA/test.tsv:388',
#  'CoLA/test.tsv:389',
#  'CoLA/test.tsv:390',
#  'CoLA/test.tsv:391',
#  'CoLA/test.tsv:392',
#  'CoLA/test.tsv:393',
#  'CoLA/test.tsv:394',
#  'CoLA/test.tsv:395',
#  'CoLA/test.tsv:396',
#  'CoLA/test.tsv:397',
#  'CoLA/test.tsv:398',
#  'CoLA/test.tsv:399',
#  'CoLA/test.tsv:400',
#  'CoLA/test.tsv:401',
#  'CoLA/test.tsv:402',
#  'CoLA/test.tsv:403',
#  'CoLA/test.tsv:404',
#  'CoLA/test.tsv:405',
#  'CoLA/test.tsv:406',
#  'CoLA/test.tsv:407',
#  'CoLA/test.tsv:408',
#  'CoLA/test.tsv:409',
#  'CoLA/test.tsv:410',
#  'CoLA/test.tsv:411',
#  'CoLA/test.tsv:412',
#  'CoLA/test.tsv:413',
#  'CoLA/test.tsv:414',
#  'CoLA/test.tsv:415',
#  'CoLA/test.tsv:416',
#  'CoLA/test.tsv:417',
#  'CoLA/test.tsv:418',
#  'CoLA/test.tsv:419',
#  'CoLA/test.tsv:420',
#  'CoLA/test.tsv:421',
#  'CoLA/test.tsv:422',
#  'CoLA/test.tsv:423',
#  'CoLA/test.tsv:424',
#  'CoLA/test.tsv:425',
#  'CoLA/test.tsv:426',
#  'CoLA/test.tsv:427',
#  'CoLA/test.tsv:428',
#  'CoLA/test.tsv:429',
#  'CoLA/test.tsv:430',
#  'CoLA/test.tsv:431',
#  'CoLA/test.tsv:432',
#  'CoLA/test.tsv:433',
#  'CoLA/test.tsv:434',
#  'CoLA/test.tsv:435',
#  'CoLA/test.tsv:436',
#  'CoLA/test.tsv:437',
#  'CoLA/test.tsv:438',
#  'CoLA/test.tsv:439',
#  'CoLA/test.tsv:440',
#  'CoLA/test.tsv:441',
#  'CoLA/test.tsv:442',
#  'CoLA/test.tsv:443',
#  'CoLA/test.tsv:444',
#  'CoLA/test.tsv:445',
#  'CoLA/test.tsv:446',
#  'CoLA/test.tsv:447',
#  'CoLA/test.tsv:448',
#  'CoLA/test.tsv:449',
#  'CoLA/test.tsv:450',
#  'CoLA/test.tsv:451',
#  'CoLA/test.tsv:452',
#  'CoLA/test.tsv:453',
#  'CoLA/test.tsv:454',
#  'CoLA/test.tsv:455',
#  'CoLA/test.tsv:456',
#  'CoLA/test.tsv:457',
#  'CoLA/test.tsv:458',
#  'CoLA/test.tsv:459',
#  'CoLA/test.tsv:460',
#  'CoLA/test.tsv:461',
#  'CoLA/test.tsv:462',
#  'CoLA/test.tsv:463',
#  'CoLA/test.tsv:464',
#  'CoLA/test.tsv:465',
#  'CoLA/test.tsv:466',
#  'CoLA/test.tsv:467',
#  'CoLA/test.tsv:468',
#  'CoLA/test.tsv:469',
#  'CoLA/test.tsv:470',
#  'CoLA/test.tsv:471',
#  'CoLA/test.tsv:472',
#  'CoLA/test.tsv:473',
#  'CoLA/test.tsv:474',
#  'CoLA/test.tsv:475',
#  'CoLA/test.tsv:476',
#  'CoLA/test.tsv:477',
#  'CoLA/test.tsv:478',
#  'CoLA/test.tsv:479',
#  'CoLA/test.tsv:480',
#  'CoLA/test.tsv:481',
#  'CoLA/test.tsv:482',
#  'CoLA/test.tsv:483',
#  'CoLA/test.tsv:484',
#  'CoLA/test.tsv:485',
#  'CoLA/test.tsv:486',
#  'CoLA/test.tsv:487',
#  'CoLA/test.tsv:488',
#  'CoLA/test.tsv:489',
#  'CoLA/test.tsv:490',
#  'CoLA/test.tsv:491',
#  'CoLA/test.tsv:492',
#  'CoLA/test.tsv:493',
#  'CoLA/test.tsv:494',
#  'CoLA/test.tsv:495',
#  'CoLA/test.tsv:496',
#  'CoLA/test.tsv:497',
#  'CoLA/test.tsv:498',
#  'CoLA/test.tsv:499',
#  'CoLA/test.tsv:500',
#  'CoLA/test.tsv:501',
#  'CoLA/test.tsv:502',
#  'CoLA/test.tsv:503',
#  'CoLA/test.tsv:504',
#  'CoLA/test.tsv:505',
#  'CoLA/test.tsv:506',
#  'CoLA/test.tsv:507',
#  'CoLA/test.tsv:508',
#  'CoLA/test.tsv:509',
#  'CoLA/test.tsv:510',
#  'CoLA/test.tsv:511',
#  'CoLA/test.tsv:512',
#  'CoLA/test.tsv:513',
#  'CoLA/test.tsv:514',
#  'CoLA/test.tsv:515',
#  'CoLA/test.tsv:516',
#  'CoLA/test.tsv:517',
#  'CoLA/test.tsv:518',
#  'CoLA/test.tsv:519',
#  'CoLA/test.tsv:520',
#  'CoLA/test.tsv:521',
#  'CoLA/test.tsv:522',
#  'CoLA/test.tsv:523',
#  'CoLA/test.tsv:524',
#  'CoLA/test.tsv:525',
#  'CoLA/test.tsv:526',
#  'CoLA/test.tsv:527',
#  'CoLA/test.tsv:528',
#  'CoLA/test.tsv:529',
#  'CoLA/test.tsv:530',
#  'CoLA/test.tsv:531',
#  'CoLA/test.tsv:532',
#  'CoLA/test.tsv:533',
#  'CoLA/test.tsv:534',
#  'CoLA/test.tsv:535',
#  'CoLA/test.tsv:536',
#  'CoLA/test.tsv:537',
#  'CoLA/test.tsv:538',
#  'CoLA/test.tsv:539',
#  'CoLA/test.tsv:540',
#  'CoLA/test.tsv:541',
#  'CoLA/test.tsv:542',
#  'CoLA/test.tsv:543',
#  'CoLA/test.tsv:544',
#  'CoLA/test.tsv:545',
#  'CoLA/test.tsv:546',
#  'CoLA/test.tsv:547',
#  'CoLA/test.tsv:548',
#  'CoLA/test.tsv:549',
#  'CoLA/test.tsv:550',
#  'CoLA/test.tsv:551',
#  'CoLA/test.tsv:552',
#  'CoLA/test.tsv:553',
#  'CoLA/test.tsv:554',
#  'CoLA/test.tsv:555',
#  'CoLA/test.tsv:556',
#  'CoLA/test.tsv:557',
#  'CoLA/test.tsv:558',
#  'CoLA/test.tsv:559',
#  'CoLA/test.tsv:560',
#  'CoLA/test.tsv:561',
#  'CoLA/test.tsv:562',
#  'CoLA/test.tsv:563',
#  'CoLA/test.tsv:564',
#  'CoLA/test.tsv:565',
#  'CoLA/test.tsv:566',
#  'CoLA/test.tsv:567',
#  'CoLA/test.tsv:568',
#  'CoLA/test.tsv:569',
#  'CoLA/test.tsv:570',
#  'CoLA/test.tsv:571',
#  'CoLA/test.tsv:572',
#  'CoLA/test.tsv:573',
#  'CoLA/test.tsv:574',
#  'CoLA/test.tsv:575',
#  'CoLA/test.tsv:576',
#  'CoLA/test.tsv:577',
#  'CoLA/test.tsv:578',
#  'CoLA/test.tsv:579',
#  'CoLA/test.tsv:580',
#  'CoLA/test.tsv:581',
#  'CoLA/test.tsv:582',
#  'CoLA/test.tsv:583',
#  'CoLA/test.tsv:584',
#  'CoLA/test.tsv:585',
#  'CoLA/test.tsv:586',
#  'CoLA/test.tsv:587',
#  'CoLA/test.tsv:588',
#  'CoLA/test.tsv:589',
#  'CoLA/test.tsv:590',
#  'CoLA/test.tsv:591',
#  'CoLA/test.tsv:592',
#  'CoLA/test.tsv:593',
#  'CoLA/test.tsv:594',
#  'CoLA/test.tsv:595',
#  'CoLA/test.tsv:596',
#  'CoLA/test.tsv:597',
#  'CoLA/test.tsv:598',
#  'CoLA/test.tsv:599',
#  'CoLA/test.tsv:600',
#  'CoLA/test.tsv:601',
#  'CoLA/test.tsv:602',
#  'CoLA/test.tsv:603',
#  'CoLA/test.tsv:604',
#  'CoLA/test.tsv:605',
#  'CoLA/test.tsv:606',
#  'CoLA/test.tsv:607',
#  'CoLA/test.tsv:608',
#  'CoLA/test.tsv:609',
#  'CoLA/test.tsv:610',
#  'CoLA/test.tsv:611',
#  'CoLA/test.tsv:612',
#  'CoLA/test.tsv:613',
#  'CoLA/test.tsv:614',
#  'CoLA/test.tsv:615',
#  'CoLA/test.tsv:616',
#  'CoLA/test.tsv:617',
#  'CoLA/test.tsv:618',
#  'CoLA/test.tsv:619',
#  'CoLA/test.tsv:620',
#  'CoLA/test.tsv:621',
#  'CoLA/test.tsv:622',
#  'CoLA/test.tsv:623',
#  'CoLA/test.tsv:624',
#  'CoLA/test.tsv:625',
#  'CoLA/test.tsv:626',
#  'CoLA/test.tsv:627',
#  'CoLA/test.tsv:628',
#  'CoLA/test.tsv:629',
#  'CoLA/test.tsv:630',
#  'CoLA/test.tsv:631',
#  'CoLA/test.tsv:632',
#  'CoLA/test.tsv:633',
#  'CoLA/test.tsv:634',
#  'CoLA/test.tsv:635',
#  'CoLA/test.tsv:636',
#  'CoLA/test.tsv:637',
#  'CoLA/test.tsv:638',
#  'CoLA/test.tsv:639',
#  'CoLA/test.tsv:640',
#  'CoLA/test.tsv:641',
#  'CoLA/test.tsv:642',
#  'CoLA/test.tsv:643',
#  'CoLA/test.tsv:644',
#  'CoLA/test.tsv:645',
#  'CoLA/test.tsv:646',
#  'CoLA/test.tsv:647',
#  'CoLA/test.tsv:648',
#  'CoLA/test.tsv:649',
#  'CoLA/test.tsv:650',
#  'CoLA/test.tsv:651',
#  'CoLA/test.tsv:652',
#  'CoLA/test.tsv:653',
#  'CoLA/test.tsv:654',
#  'CoLA/test.tsv:655',
#  'CoLA/test.tsv:656',
#  'CoLA/test.tsv:657',
#  'CoLA/test.tsv:658',
#  'CoLA/test.tsv:659',
#  'CoLA/test.tsv:660',
#  'CoLA/test.tsv:661',
#  'CoLA/test.tsv:662',
#  'CoLA/test.tsv:663',
#  'CoLA/test.tsv:664',
#  'CoLA/test.tsv:665',
#  'CoLA/test.tsv:666',
#  'CoLA/test.tsv:667',
#  'CoLA/test.tsv:668',
#  'CoLA/test.tsv:669',
#  'CoLA/test.tsv:670',
#  'CoLA/test.tsv:671',
#  'CoLA/test.tsv:672',
#  'CoLA/test.tsv:673',
#  'CoLA/test.tsv:674',
#  'CoLA/test.tsv:675',
#  'CoLA/test.tsv:676',
#  'CoLA/test.tsv:677',
#  'CoLA/test.tsv:678',
#  'CoLA/test.tsv:679',
#  'CoLA/test.tsv:680',
#  'CoLA/test.tsv:681',
#  'CoLA/test.tsv:682',
#  'CoLA/test.tsv:683',
#  'CoLA/test.tsv:684',
#  'CoLA/test.tsv:685',
#  'CoLA/test.tsv:686',
#  'CoLA/test.tsv:687',
#  'CoLA/test.tsv:688',
#  'CoLA/test.tsv:689',
#  'CoLA/test.tsv:690',
#  'CoLA/test.tsv:691',
#  'CoLA/test.tsv:692',
#  'CoLA/test.tsv:693',
#  'CoLA/test.tsv:694',
#  'CoLA/test.tsv:695',
#  'CoLA/test.tsv:696',
#  'CoLA/test.tsv:697',
#  'CoLA/test.tsv:698',
#  'CoLA/test.tsv:699',
#  'CoLA/test.tsv:700',
#  'CoLA/test.tsv:701',
#  'CoLA/test.tsv:702',
#  'CoLA/test.tsv:703',
#  'CoLA/test.tsv:704',
#  'CoLA/test.tsv:705',
#  'CoLA/test.tsv:706',
#  'CoLA/test.tsv:707',
#  'CoLA/test.tsv:708',
#  'CoLA/test.tsv:709',
#  'CoLA/test.tsv:710',
#  'CoLA/test.tsv:711',
#  'CoLA/test.tsv:712',
#  'CoLA/test.tsv:713',
#  'CoLA/test.tsv:714',
#  'CoLA/test.tsv:715',
#  'CoLA/test.tsv:716',
#  'CoLA/test.tsv:717',
#  'CoLA/test.tsv:718',
#  'CoLA/test.tsv:719',
#  'CoLA/test.tsv:720',
#  'CoLA/test.tsv:721',
#  'CoLA/test.tsv:722',
#  'CoLA/test.tsv:723',
#  'CoLA/test.tsv:724',
#  'CoLA/test.tsv:725',
#  'CoLA/test.tsv:726',
#  'CoLA/test.tsv:727',
#  'CoLA/test.tsv:728',
#  'CoLA/test.tsv:729',
#  'CoLA/test.tsv:730',
#  'CoLA/test.tsv:731',
#  'CoLA/test.tsv:732',
#  'CoLA/test.tsv:733',
#  'CoLA/test.tsv:734',
#  'CoLA/test.tsv:735',
#  'CoLA/test.tsv:736',
#  'CoLA/test.tsv:737',
#  'CoLA/test.tsv:738',
#  'CoLA/test.tsv:739',
#  'CoLA/test.tsv:740',
#  'CoLA/test.tsv:741',
#  'CoLA/test.tsv:742',
#  'CoLA/test.tsv:743',
#  'CoLA/test.tsv:744',
#  'CoLA/test.tsv:745',
#  'CoLA/test.tsv:746',
#  'CoLA/test.tsv:747',
#  'CoLA/test.tsv:748',
#  'CoLA/test.tsv:749',
#  'CoLA/test.tsv:750',
#  'CoLA/test.tsv:751',
#  'CoLA/test.tsv:752',
#  'CoLA/test.tsv:753',
#  'CoLA/test.tsv:754',
#  'CoLA/test.tsv:755',
#  'CoLA/test.tsv:756',
#  'CoLA/test.tsv:757',
#  'CoLA/test.tsv:758',
#  'CoLA/test.tsv:759',
#  'CoLA/test.tsv:760',
#  'CoLA/test.tsv:761',
#  'CoLA/test.tsv:762',
#  'CoLA/test.tsv:763',
#  'CoLA/test.tsv:764',
#  'CoLA/test.tsv:765',
#  'CoLA/test.tsv:766',
#  'CoLA/test.tsv:767',
#  'CoLA/test.tsv:768',
#  'CoLA/test.tsv:769',
#  'CoLA/test.tsv:770',
#  'CoLA/test.tsv:771',
#  'CoLA/test.tsv:772',
#  'CoLA/test.tsv:773',
#  'CoLA/test.tsv:774',
#  'CoLA/test.tsv:775',
#  'CoLA/test.tsv:776',
#  'CoLA/test.tsv:777',
#  'CoLA/test.tsv:778',
#  'CoLA/test.tsv:779',
#  'CoLA/test.tsv:780',
#  'CoLA/test.tsv:781',
#  'CoLA/test.tsv:782',
#  'CoLA/test.tsv:783',
#  'CoLA/test.tsv:784',
#  'CoLA/test.tsv:785',
#  'CoLA/test.tsv:786',
#  'CoLA/test.tsv:787',
#  'CoLA/test.tsv:788',
#  'CoLA/test.tsv:789',
#  'CoLA/test.tsv:790',
#  'CoLA/test.tsv:791',
#  'CoLA/test.tsv:792',
#  'CoLA/test.tsv:793',
#  'CoLA/test.tsv:794',
#  'CoLA/test.tsv:795',
#  'CoLA/test.tsv:796',
#  'CoLA/test.tsv:797',
#  'CoLA/test.tsv:798',
#  'CoLA/test.tsv:799',
#  'CoLA/test.tsv:800',
#  'CoLA/test.tsv:801',
#  'CoLA/test.tsv:802',
#  'CoLA/test.tsv:803',
#  'CoLA/test.tsv:804',
#  'CoLA/test.tsv:805',
#  'CoLA/test.tsv:806',
#  'CoLA/test.tsv:807',
#  'CoLA/test.tsv:808',
#  'CoLA/test.tsv:809',
#  'CoLA/test.tsv:810',
#  'CoLA/test.tsv:811',
#  'CoLA/test.tsv:812',
#  'CoLA/test.tsv:813',
#  'CoLA/test.tsv:814',
#  'CoLA/test.tsv:815',
#  'CoLA/test.tsv:816',
#  'CoLA/test.tsv:817',
#  'CoLA/test.tsv:818',
#  'CoLA/test.tsv:819',
#  'CoLA/test.tsv:820',
#  'CoLA/test.tsv:821',
#  'CoLA/test.tsv:822',
#  'CoLA/test.tsv:823',
#  'CoLA/test.tsv:824',
#  'CoLA/test.tsv:825',
#  'CoLA/test.tsv:826',
#  'CoLA/test.tsv:827',
#  'CoLA/test.tsv:828',
#  'CoLA/test.tsv:829',
#  'CoLA/test.tsv:830',
#  'CoLA/test.tsv:831',
#  'CoLA/test.tsv:832',
#  'CoLA/test.tsv:833',
#  'CoLA/test.tsv:834',
#  'CoLA/test.tsv:835',
#  'CoLA/test.tsv:836',
#  'CoLA/test.tsv:837',
#  'CoLA/test.tsv:838',
#  'CoLA/test.tsv:839',
#  'CoLA/test.tsv:840',
#  'CoLA/test.tsv:841',
#  'CoLA/test.tsv:842',
#  'CoLA/test.tsv:843',
#  'CoLA/test.tsv:844',
#  'CoLA/test.tsv:845',
#  'CoLA/test.tsv:846',
#  'CoLA/test.tsv:847',
#  'CoLA/test.tsv:848',
#  'CoLA/test.tsv:849',
#  'CoLA/test.tsv:850',
#  'CoLA/test.tsv:851',
#  'CoLA/test.tsv:852',
#  'CoLA/test.tsv:853',
#  'CoLA/test.tsv:854',
#  'CoLA/test.tsv:855',
#  'CoLA/test.tsv:856',
#  'CoLA/test.tsv:857',
#  'CoLA/test.tsv:858',
#  'CoLA/test.tsv:859',
#  'CoLA/test.tsv:860',
#  'CoLA/test.tsv:861',
#  'CoLA/test.tsv:862',
#  'CoLA/test.tsv:863',
#  'CoLA/test.tsv:864',
#  'CoLA/test.tsv:865',
#  'CoLA/test.tsv:866',
#  'CoLA/test.tsv:867',
#  'CoLA/test.tsv:868',
#  'CoLA/test.tsv:869',
#  'CoLA/test.tsv:870',
#  'CoLA/test.tsv:871',
#  'CoLA/test.tsv:872',
#  'CoLA/test.tsv:873',
#  'CoLA/test.tsv:874',
#  'CoLA/test.tsv:875',
#  'CoLA/test.tsv:876',
#  'CoLA/test.tsv:877',
#  'CoLA/test.tsv:878',
#  'CoLA/test.tsv:879',
#  'CoLA/test.tsv:880',
#  'CoLA/test.tsv:881',
#  'CoLA/test.tsv:882',
#  'CoLA/test.tsv:883',
#  'CoLA/test.tsv:884',
#  'CoLA/test.tsv:885',
#  'CoLA/test.tsv:886',
#  'CoLA/test.tsv:887',
#  'CoLA/test.tsv:888',
#  'CoLA/test.tsv:889',
#  'CoLA/test.tsv:890',
#  'CoLA/test.tsv:891',
#  'CoLA/test.tsv:892',
#  'CoLA/test.tsv:893',
#  'CoLA/test.tsv:894',
#  'CoLA/test.tsv:895',
#  'CoLA/test.tsv:896',
#  'CoLA/test.tsv:897',
#  'CoLA/test.tsv:898',
#  'CoLA/test.tsv:899',
#  'CoLA/test.tsv:900',
#  'CoLA/test.tsv:901',
#  'CoLA/test.tsv:902',
#  'CoLA/test.tsv:903',
#  'CoLA/test.tsv:904',
#  'CoLA/test.tsv:905',
#  'CoLA/test.tsv:906',
#  'CoLA/test.tsv:907',
#  'CoLA/test.tsv:908',
#  'CoLA/test.tsv:909',
#  'CoLA/test.tsv:910',
#  'CoLA/test.tsv:911',
#  'CoLA/test.tsv:912',
#  'CoLA/test.tsv:913',
#  'CoLA/test.tsv:914',
#  'CoLA/test.tsv:915',
#  'CoLA/test.tsv:916',
#  'CoLA/test.tsv:917',
#  'CoLA/test.tsv:918',
#  'CoLA/test.tsv:919',
#  'CoLA/test.tsv:920',
#  'CoLA/test.tsv:921',
#  'CoLA/test.tsv:922',
#  'CoLA/test.tsv:923',
#  'CoLA/test.tsv:924',
#  'CoLA/test.tsv:925',
#  'CoLA/test.tsv:926',
#  'CoLA/test.tsv:927',
#  'CoLA/test.tsv:928',
#  'CoLA/test.tsv:929',
#  'CoLA/test.tsv:930',
#  'CoLA/test.tsv:931',
#  'CoLA/test.tsv:932',
#  'CoLA/test.tsv:933',
#  'CoLA/test.tsv:934',
#  'CoLA/test.tsv:935',
#  'CoLA/test.tsv:936',
#  'CoLA/test.tsv:937',
#  'CoLA/test.tsv:938',
#  'CoLA/test.tsv:939',
#  'CoLA/test.tsv:940',
#  'CoLA/test.tsv:941',
#  'CoLA/test.tsv:942',
#  'CoLA/test.tsv:943',
#  'CoLA/test.tsv:944',
#  'CoLA/test.tsv:945',
#  'CoLA/test.tsv:946',
#  'CoLA/test.tsv:947',
#  'CoLA/test.tsv:948',
#  'CoLA/test.tsv:949',
#  'CoLA/test.tsv:950',
#  'CoLA/test.tsv:951',
#  'CoLA/test.tsv:952',
#  'CoLA/test.tsv:953',
#  'CoLA/test.tsv:954',
#  'CoLA/test.tsv:955',
#  'CoLA/test.tsv:956',
#  'CoLA/test.tsv:957',
#  'CoLA/test.tsv:958',
#  'CoLA/test.tsv:959',
#  'CoLA/test.tsv:960',
#  'CoLA/test.tsv:961',
#  'CoLA/test.tsv:962',
#  'CoLA/test.tsv:963',
#  'CoLA/test.tsv:964',
#  'CoLA/test.tsv:965',
#  'CoLA/test.tsv:966',
#  'CoLA/test.tsv:967',
#  'CoLA/test.tsv:968',
#  'CoLA/test.tsv:969',
#  'CoLA/test.tsv:970',
#  'CoLA/test.tsv:971',
#  'CoLA/test.tsv:972',
#  'CoLA/test.tsv:973',
#  'CoLA/test.tsv:974',
#  'CoLA/test.tsv:975',
#  'CoLA/test.tsv:976',
#  'CoLA/test.tsv:977',
#  'CoLA/test.tsv:978',
#  'CoLA/test.tsv:979',
#  'CoLA/test.tsv:980',
#  'CoLA/test.tsv:981',
#  'CoLA/test.tsv:982',
#  'CoLA/test.tsv:983',
#  'CoLA/test.tsv:984',
#  'CoLA/test.tsv:985',
#  'CoLA/test.tsv:986',
#  'CoLA/test.tsv:987',
#  'CoLA/test.tsv:988',
#  'CoLA/test.tsv:989',
#  'CoLA/test.tsv:990',
#  'CoLA/test.tsv:991',
#  'CoLA/test.tsv:992',
#  'CoLA/test.tsv:993',
#  'CoLA/test.tsv:994',
#  'CoLA/test.tsv:995',
#  'CoLA/test.tsv:996',
#  'CoLA/test.tsv:997',
#  'CoLA/test.tsv:998',
#  'CoLA/test.tsv:999',
#  'CoLA/test.tsv:1000',
#  'CoLA/test.tsv:1001',
#  ...]

# %%
from tagger import Tagger
tagger = Tagger()

# %%
import random
for uid in random.sample(COLA_test_uids, 32):
    tagger.add_tag(uid, 'test')

# %%
test_uids = tagger.get_uids('test')
test_uids
# Out:
# ['CoLA/test.tsv:1011',
#  'CoLA/test.tsv:1021',
#  'CoLA/test.tsv:1023',
#  'CoLA/test.tsv:1026',
#  'CoLA/test.tsv:1052',
#  'CoLA/test.tsv:1059',
#  'CoLA/test.tsv:155',
#  'CoLA/test.tsv:157',
#  'CoLA/test.tsv:172',
#  'CoLA/test.tsv:18',
#  'CoLA/test.tsv:183',
#  'CoLA/test.tsv:185',
#  'CoLA/test.tsv:19',
#  'CoLA/test.tsv:193',
#  'CoLA/test.tsv:2',
#  'CoLA/test.tsv:204',
#  'CoLA/test.tsv:220',
#  'CoLA/test.tsv:259',
#  'CoLA/test.tsv:262',
#  'CoLA/test.tsv:276',
#  'CoLA/test.tsv:330',
#  'CoLA/test.tsv:371',
#  'CoLA/test.tsv:383',
#  'CoLA/test.tsv:386',
#  'CoLA/test.tsv:402',
#  'CoLA/test.tsv:406',
#  'CoLA/test.tsv:407',
#  'CoLA/test.tsv:452',
#  'CoLA/test.tsv:461',
#  'CoLA/test.tsv:470',
#  'CoLA/test.tsv:480',
#  'CoLA/test.tsv:5',
#  'CoLA/test.tsv:523',
#  'CoLA/test.tsv:538',
#  'CoLA/test.tsv:547',
#  'CoLA/test.tsv:589',
#  'CoLA/test.tsv:608',
#  'CoLA/test.tsv:613',
#  'CoLA/test.tsv:631',
#  'CoLA/test.tsv:639',
#  'CoLA/test.tsv:64',
#  'CoLA/test.tsv:642',
#  'CoLA/test.tsv:649',
#  'CoLA/test.tsv:656',
#  'CoLA/test.tsv:658',
#  'CoLA/test.tsv:678',
#  'CoLA/test.tsv:696',
#  'CoLA/test.tsv:718',
#  'CoLA/test.tsv:724',
#  'CoLA/test.tsv:73',
#  'CoLA/test.tsv:749',
#  'CoLA/test.tsv:759',
#  'CoLA/test.tsv:766',
#  'CoLA/test.tsv:78',
#  'CoLA/test.tsv:782',
#  'CoLA/test.tsv:832',
#  'CoLA/test.tsv:842',
#  'CoLA/test.tsv:862',
#  'CoLA/test.tsv:875',
#  'CoLA/test.tsv:902',
#  'CoLA/test.tsv:963',
#  'CoLA/test.tsv:979']

# %%
some_uid = test_uids[0]
tagger.remove_tag(some_uid, 'test')
test_uids = tagger.get_uids('test')
some_uid, len(test_uids)
# Out:
# ('CoLA/test.tsv:1011', 61)

# %%
tagger.get_uids('test')
# Out:
# ['CoLA/test.tsv:1021',
#  'CoLA/test.tsv:1023',
#  'CoLA/test.tsv:1026',
#  'CoLA/test.tsv:1052',
#  'CoLA/test.tsv:1059',
#  'CoLA/test.tsv:155',
#  'CoLA/test.tsv:157',
#  'CoLA/test.tsv:172',
#  'CoLA/test.tsv:18',
#  'CoLA/test.tsv:183',
#  'CoLA/test.tsv:185',
#  'CoLA/test.tsv:19',
#  'CoLA/test.tsv:193',
#  'CoLA/test.tsv:2',
#  'CoLA/test.tsv:204',
#  'CoLA/test.tsv:220',
#  'CoLA/test.tsv:259',
#  'CoLA/test.tsv:262',
#  'CoLA/test.tsv:276',
#  'CoLA/test.tsv:330',
#  'CoLA/test.tsv:371',
#  'CoLA/test.tsv:383',
#  'CoLA/test.tsv:386',
#  'CoLA/test.tsv:402',
#  'CoLA/test.tsv:406',
#  'CoLA/test.tsv:407',
#  'CoLA/test.tsv:452',
#  'CoLA/test.tsv:461',
#  'CoLA/test.tsv:470',
#  'CoLA/test.tsv:480',
#  'CoLA/test.tsv:5',
#  'CoLA/test.tsv:523',
#  'CoLA/test.tsv:538',
#  'CoLA/test.tsv:547',
#  'CoLA/test.tsv:589',
#  'CoLA/test.tsv:608',
#  'CoLA/test.tsv:613',
#  'CoLA/test.tsv:631',
#  'CoLA/test.tsv:639',
#  'CoLA/test.tsv:64',
#  'CoLA/test.tsv:642',
#  'CoLA/test.tsv:649',
#  'CoLA/test.tsv:656',
#  'CoLA/test.tsv:658',
#  'CoLA/test.tsv:678',
#  'CoLA/test.tsv:696',
#  'CoLA/test.tsv:718',
#  'CoLA/test.tsv:724',
#  'CoLA/test.tsv:73',
#  'CoLA/test.tsv:749',
#  'CoLA/test.tsv:759',
#  'CoLA/test.tsv:766',
#  'CoLA/test.tsv:78',
#  'CoLA/test.tsv:782',
#  'CoLA/test.tsv:832',
#  'CoLA/test.tsv:842',
#  'CoLA/test.tsv:862',
#  'CoLA/test.tsv:875',
#  'CoLA/test.tsv:902',
#  'CoLA/test.tsv:963',
#  'CoLA/test.tsv:979']

# %%
# ensure that we are not shuffling
assert isinstance(
    dl.sampler,
    torch.utils.data.sampler.SequentialSampler
)

df_error = create_dataframe(task_name,model,dl, test_uids)
print('created dataframe')
df_error
# Out:
# 1063it [00:01, 846.33it/s]
# created dataframe
#                                             sentence1 sentence2     score  \
# 0                     bill whistled past the house .             0.984186
# 1           the kitten ##s yawned awake and played .             0.992899
# 2    which problem do you wonder whether john said...            0.013048
# 3                             they could have left .             0.989907
# 4    what books does a critic think are read ##abl...            0.362239
# 5      he threw into the waste ##basket the letter .             0.013369
# 6     jack is making the claim you won ' t need it .             0.732179
# 7    the men were able to mine more gold from the ...            0.992576
# 8                 this list includes my name on it .             0.990762
# 9                       steve tossed anna the ball .             0.993051
# 10                           martha car ##ves toys .             0.988687
# 11                david constructed a house for me .             0.991776
# 12                       heather cable ##d to sara .             0.994106
# 13                             snow white poisoned .             0.013785
# 14             the room contains many armchair ##s .             0.991141
# 15                               they write to her .             0.991531
# 16   the soldiers must enforce bill to make the ba...            0.112475
# 17   pat was persuaded to be examined by the denti...            0.991965
# 18   it was only gradually that i came to realize ...            0.983340
# 19             john kissed the b ##lar ##ney stone .             0.991593
# 20        heidi said that john loves peanut butter .             0.994114
# 21                           we ' re all at school .             0.993077
# 22         peter placed the letter in the envelope .             0.993290
# 23                 she made jerry out to be famous .             0.291246
# 24                i know which guys you ' ve dated .             0.987296
# 25   on your desk , this girl in the red coat will...            0.013707
# 26                    i prefer for the girl to won .             0.097519
# 27   john will have been enthusiastically eating c...            0.994253
# 28                  they like each other ' s books .             0.989162
# 29    they are going home for to see their parents .             0.018172
# ..                                                ...       ...       ...
# 31           they noticed the painting for an hour .             0.850156
# 32   why is sandy wondering whether there will be ...            0.989956
# 33       breakfast is eaten by the camp ##ers nude .             0.345476
# 34                i was convinced by john to leave .             0.991470
# 35   books were taken from no student by any profe...            0.843840
# 36    bill ate the peach ##es and harry the grapes .             0.052203
# 37   simon quickly dropped the gold , and jack sud...            0.017526
# 38   charlie went into the bedroom at 5 : 30 , and...            0.981501
# 39   harry told sue , and tom sally , that albania...            0.819772
# 40   frank forced tom to shave himself , and sam ,...            0.064381
# 41   k ##lem ##per ##er ' s recording of ives ' 1s...            0.713680
# 42                      i think that who went home .             0.066556
# 43                   i wonder whom for us to trust .             0.016586
# 44   every essay she ' s written and which i ' ve ...            0.451673
# 45           leslie told ourselves about ourselves .             0.019453
# 46               we wrapped the blankets around us .             0.995737
# 47                          they will run the risk .             0.919654
# 48              some people yell at the noisy dogs .             0.992369
# 49                           we relied over leslie .             0.531010
# 50             the storm arrived during the picnic .             0.928088
# 51                            a rat yesterday died .             0.972072
# 52                              she enjoys himself .             0.013414
# 53                            jan gave dale a book .             0.991485
# 54   that the media discuss celebrities ' sex live...            0.988593
# 55                           john ate the meat raw .             0.995802
# 56                         i bought a book to read .             0.993625
# 57                             i want to meet at 6 .             0.981151
# 58           the arrival of john dead surprised me .             0.896392
# 59                i wrote a letter to bill to read .             0.927732
# 60   john thinks that it is appropriate for there ...            0.992431
#
#     label                 uid  is_wrong
# 0      -1     CoLA/test.tsv:2      True
# 1      -1     CoLA/test.tsv:5      True
# 2      -1    CoLA/test.tsv:18      True
# 3      -1    CoLA/test.tsv:19      True
# 4      -1    CoLA/test.tsv:64      True
# 5      -1    CoLA/test.tsv:73      True
# 6      -1    CoLA/test.tsv:78      True
# 7      -1   CoLA/test.tsv:155      True
# 8      -1   CoLA/test.tsv:157      True
# 9      -1   CoLA/test.tsv:172      True
# 10     -1   CoLA/test.tsv:183      True
# 11     -1   CoLA/test.tsv:185      True
# 12     -1   CoLA/test.tsv:193      True
# 13     -1   CoLA/test.tsv:204      True
# 14     -1   CoLA/test.tsv:220      True
# 15     -1   CoLA/test.tsv:259      True
# 16     -1   CoLA/test.tsv:262      True
# 17     -1   CoLA/test.tsv:276      True
# 18     -1   CoLA/test.tsv:330      True
# 19     -1   CoLA/test.tsv:371      True
# 20     -1   CoLA/test.tsv:383      True
# 21     -1   CoLA/test.tsv:386      True
# 22     -1   CoLA/test.tsv:402      True
# 23     -1   CoLA/test.tsv:406      True
# 24     -1   CoLA/test.tsv:407      True
# 25     -1   CoLA/test.tsv:452      True
# 26     -1   CoLA/test.tsv:461      True
# 27     -1   CoLA/test.tsv:470      True
# 28     -1   CoLA/test.tsv:480      True
# 29     -1   CoLA/test.tsv:523      True
# ..    ...                 ...       ...
# 31     -1   CoLA/test.tsv:547      True
# 32     -1   CoLA/test.tsv:589      True
# 33     -1   CoLA/test.tsv:608      True
# 34     -1   CoLA/test.tsv:613      True
# 35     -1   CoLA/test.tsv:631      True
# 36     -1   CoLA/test.tsv:639      True
# 37     -1   CoLA/test.tsv:642      True
# 38     -1   CoLA/test.tsv:649      True
# 39     -1   CoLA/test.tsv:656      True
# 40     -1   CoLA/test.tsv:658      True
# 41     -1   CoLA/test.tsv:678      True
# 42     -1   CoLA/test.tsv:696      True
# 43     -1   CoLA/test.tsv:718      True
# 44     -1   CoLA/test.tsv:724      True
# 45     -1   CoLA/test.tsv:749      True
# 46     -1   CoLA/test.tsv:759      True
# 47     -1   CoLA/test.tsv:766      True
# 48     -1   CoLA/test.tsv:782      True
# 49     -1   CoLA/test.tsv:832      True
# 50     -1   CoLA/test.tsv:842      True
# 51     -1   CoLA/test.tsv:862      True
# 52     -1   CoLA/test.tsv:875      True
# 53     -1   CoLA/test.tsv:902      True
# 54     -1   CoLA/test.tsv:963      True
# 55     -1   CoLA/test.tsv:979      True
# 56     -1  CoLA/test.tsv:1021      True
# 57     -1  CoLA/test.tsv:1023      True
# 58     -1  CoLA/test.tsv:1026      True
# 59     -1  CoLA/test.tsv:1052      True
# 60     -1  CoLA/test.tsv:1059      True
#
# [61 rows x 6 columns]

# %%
len(df_error), len(test_uids)
# Out:
# (61, 61)
