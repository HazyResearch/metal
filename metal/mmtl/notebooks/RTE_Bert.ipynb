# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, Dataset
import numpy as np
import pandas as pd
import metal
import os
from pytorch_pretrained_bert import BertTokenizer, BertModel
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
from dataset import BERTDataset

# %%
model = 'bert-base-uncased' # also try bert-base-multilingual-cased (recommended)
src_path = os.path.join(os.environ['GLUEDATA'], 'RTE/{}.tsv')
dataloaders = {}
for split in ['train', 'dev']: #, 'train', 'test']:
    label_idx = 3 if split in ['train', 'dev'] else -1
    dataset = BERTDataset(
        src_path.format(split),
        sent1_idx=1,
        sent2_idx=2,
        label_idx=label_idx,
        skip_rows=1,
        label_fn=lambda label: 1 if label=='entailment' else 2,
        max_len=128,
    )
    dataloaders[split] = dataset.get_dataloader(batch_size=32)
# Out:
# 100%|██████████| 2490/2490 [00:02<00:00, 1011.58it/s]
# 100%|██████████| 277/277 [00:00<00:00, 797.56it/s]

# %%
import torch.nn as nn
from metal.end_model import EndModel

hidden_dropout_prob = 0.1

class BertEncoder(nn.Module):
    def __init__(self):
        super(BertEncoder, self).__init__()
        self.bert_model = BertModel.from_pretrained('bert-base-uncased')
        self.dropout = nn.Dropout(hidden_dropout_prob)
#         for param in self.bert_model.parameters():
#             param.requires_grad = False

    def forward(self, data):
        tokens, segments, mask = data
        # TODO: check if we should return all layers or just last hidden representation 
        _, hidden_layer = self.bert_model(tokens, segments, mask, output_all_encoded_layers=False)
        hidden_layer = self.dropout(hidden_layer)

        return hidden_layer

# %%
encoder_module = BertEncoder()
end_model = EndModel(
    [768, 2],
    input_module=encoder_module,
    seed=123,
    skip_head=False,
    input_relu=False,
    input_batchnorm=False,
    verbose=False,
    device=torch.device("cuda")
)

# %%
end_model.train_model(
    dataloaders["train"],
    valid_data=dataloaders["dev"],
    lr=5e-5,
    l2=0,
    n_epochs=5,
#     checkpoint_metric="model/train/loss",
    checkpoint_metric="valid/accuracy",
    log_unit="batches",
    checkpoint_metric_mode="max",
    verbose=True,
    progress_bar=True,
)
# Out:
# Using GPU...
# [1 bat (0.00 epo)]: TRAIN:[loss=0.682] VALID:[accuracy=0.527]
# Saving model at iteration 1 with best score 0.527
# [2 bat (0.00 epo)]: TRAIN:[loss=0.790] VALID:[accuracy=0.527]
# [3 bat (0.00 epo)]: TRAIN:[loss=0.662] VALID:[accuracy=0.527]
# [4 bat (0.00 epo)]: TRAIN:[loss=0.736] VALID:[accuracy=0.491]
# [5 bat (0.01 epo)]: TRAIN:[loss=0.735] VALID:[accuracy=0.473]
# [6 bat (0.01 epo)]: TRAIN:[loss=0.728] VALID:[accuracy=0.473]
# [7 bat (0.01 epo)]: TRAIN:[loss=0.665] VALID:[accuracy=0.473]
# [8 bat (0.01 epo)]: TRAIN:[loss=0.710] VALID:[accuracy=0.473]
# [9 bat (0.01 epo)]: TRAIN:[loss=0.644] VALID:[accuracy=0.473]
# [10 bat (0.01 epo)]: TRAIN:[loss=0.704] VALID:[accuracy=0.473]
# [11 bat (0.01 epo)]: TRAIN:[loss=0.744] VALID:[accuracy=0.473]
# [12 bat (0.01 epo)]: TRAIN:[loss=0.733] VALID:[accuracy=0.473]
# [13 bat (0.02 epo)]: TRAIN:[loss=0.681] VALID:[accuracy=0.487]
# [14 bat (0.02 epo)]: TRAIN:[loss=0.714] VALID:[accuracy=0.509]
# [15 bat (0.02 epo)]: TRAIN:[loss=0.708] VALID:[accuracy=0.560]
# Saving model at iteration 15 with best score 0.560
# [16 bat (0.02 epo)]: TRAIN:[loss=0.702] VALID:[accuracy=0.560]
# [17 bat (0.02 epo)]: TRAIN:[loss=0.672] VALID:[accuracy=0.556]
# [18 bat (0.02 epo)]: TRAIN:[loss=0.696] VALID:[accuracy=0.549]
# [19 bat (0.02 epo)]: TRAIN:[loss=0.709] VALID:[accuracy=0.549]
# [20 bat (0.02 epo)]: TRAIN:[loss=0.696] VALID:[accuracy=0.556]
# [21 bat (0.03 epo)]: TRAIN:[loss=0.674] VALID:[accuracy=0.563]
# Saving model at iteration 21 with best score 0.563
# [22 bat (0.03 epo)]: TRAIN:[loss=0.703] VALID:[accuracy=0.563]
# [23 bat (0.03 epo)]: TRAIN:[loss=0.726] VALID:[accuracy=0.556]
# [24 bat (0.03 epo)]: TRAIN:[loss=0.722] VALID:[accuracy=0.570]
# Saving model at iteration 24 with best score 0.570
# [25 bat (0.03 epo)]: TRAIN:[loss=0.664] VALID:[accuracy=0.552]
# [26 bat (0.03 epo)]: TRAIN:[loss=0.714] VALID:[accuracy=0.560]
# [27 bat (0.03 epo)]: TRAIN:[loss=0.681] VALID:[accuracy=0.516]
# [28 bat (0.03 epo)]: TRAIN:[loss=0.677] VALID:[accuracy=0.520]
# [29 bat (0.03 epo)]: TRAIN:[loss=0.695] VALID:[accuracy=0.534]
# [30 bat (0.04 epo)]: TRAIN:[loss=0.663] VALID:[accuracy=0.578]
# Saving model at iteration 30 with best score 0.578
# [31 bat (0.04 epo)]: TRAIN:[loss=0.666] VALID:[accuracy=0.542]
# [32 bat (0.04 epo)]: TRAIN:[loss=0.684] VALID:[accuracy=0.567]
# [33 bat (0.04 epo)]: TRAIN:[loss=0.672] VALID:[accuracy=0.588]
# Saving model at iteration 33 with best score 0.588
# [34 bat (0.04 epo)]: TRAIN:[loss=0.649] VALID:[accuracy=0.578]
# [35 bat (0.04 epo)]: TRAIN:[loss=0.650] VALID:[accuracy=0.588]
# [36 bat (0.04 epo)]: TRAIN:[loss=0.684] VALID:[accuracy=0.592]
# Saving model at iteration 36 with best score 0.592
# [37 bat (0.04 epo)]: TRAIN:[loss=0.719] VALID:[accuracy=0.588]
# [38 bat (0.05 epo)]: TRAIN:[loss=0.654] VALID:[accuracy=0.585]
# [39 bat (0.05 epo)]: TRAIN:[loss=0.636] VALID:[accuracy=0.585]
# [40 bat (0.05 epo)]: TRAIN:[loss=0.712] VALID:[accuracy=0.581]
# [41 bat (0.05 epo)]: TRAIN:[loss=0.670] VALID:[accuracy=0.570]
# [42 bat (0.05 epo)]: TRAIN:[loss=0.592] VALID:[accuracy=0.574]
# [43 bat (0.05 epo)]: TRAIN:[loss=0.645] VALID:[accuracy=0.574]
# [44 bat (0.05 epo)]: TRAIN:[loss=0.593] VALID:[accuracy=0.556]
# [45 bat (0.05 epo)]: TRAIN:[loss=0.711] VALID:[accuracy=0.560]
# [46 bat (0.06 epo)]: TRAIN:[loss=0.633] VALID:[accuracy=0.563]
# [47 bat (0.06 epo)]: TRAIN:[loss=0.637] VALID:[accuracy=0.567]
# [48 bat (0.06 epo)]: TRAIN:[loss=0.583] VALID:[accuracy=0.574]
# [49 bat (0.06 epo)]: TRAIN:[loss=0.723] VALID:[accuracy=0.581]
# [50 bat (0.06 epo)]: TRAIN:[loss=0.630] VALID:[accuracy=0.588]
# [51 bat (0.06 epo)]: TRAIN:[loss=0.666] VALID:[accuracy=0.578]
# [52 bat (0.06 epo)]: TRAIN:[loss=0.605] VALID:[accuracy=0.567]
# [53 bat (0.06 epo)]: TRAIN:[loss=0.608] VALID:[accuracy=0.578]
# [54 bat (0.07 epo)]: TRAIN:[loss=0.622] VALID:[accuracy=0.567]
# [55 bat (0.07 epo)]: TRAIN:[loss=0.739] VALID:[accuracy=0.603]
# Saving model at iteration 55 with best score 0.603
# [56 bat (0.07 epo)]: TRAIN:[loss=0.612] VALID:[accuracy=0.603]
# [57 bat (0.07 epo)]: TRAIN:[loss=0.766] VALID:[accuracy=0.592]
# [58 bat (0.07 epo)]: TRAIN:[loss=0.618] VALID:[accuracy=0.596]
# [59 bat (0.07 epo)]: TRAIN:[loss=0.538] VALID:[accuracy=0.581]
# [60 bat (0.07 epo)]: TRAIN:[loss=0.702] VALID:[accuracy=0.596]
# [61 bat (0.07 epo)]: TRAIN:[loss=0.663] VALID:[accuracy=0.588]
# [62 bat (0.07 epo)]: TRAIN:[loss=0.537] VALID:[accuracy=0.581]
# [63 bat (0.08 epo)]: TRAIN:[loss=0.738] VALID:[accuracy=0.606]
# Saving model at iteration 63 with best score 0.606
# [64 bat (0.08 epo)]: TRAIN:[loss=0.635] VALID:[accuracy=0.606]
# [65 bat (0.08 epo)]: TRAIN:[loss=0.736] VALID:[accuracy=0.599]
# [66 bat (0.08 epo)]: TRAIN:[loss=0.717] VALID:[accuracy=0.585]
# [67 bat (0.08 epo)]: TRAIN:[loss=0.560] VALID:[accuracy=0.581]
# [68 bat (0.08 epo)]: TRAIN:[loss=0.694] VALID:[accuracy=0.592]
# [69 bat (0.08 epo)]: TRAIN:[loss=0.556] VALID:[accuracy=0.585]
# [70 bat (0.08 epo)]: TRAIN:[loss=0.654] VALID:[accuracy=0.596]
# [71 bat (0.09 epo)]: TRAIN:[loss=0.754] VALID:[accuracy=0.592]
# [72 bat (0.09 epo)]: TRAIN:[loss=0.546] VALID:[accuracy=0.610]
# Saving model at iteration 72 with best score 0.610
# [73 bat (0.09 epo)]: TRAIN:[loss=0.667] VALID:[accuracy=0.599]
# [74 bat (0.09 epo)]: TRAIN:[loss=0.675] VALID:[accuracy=0.603]
# [75 bat (0.09 epo)]: TRAIN:[loss=0.594] VALID:[accuracy=0.592]
# [76 bat (0.09 epo)]: TRAIN:[loss=0.707] VALID:[accuracy=0.599]
# [77 bat (0.09 epo)]: TRAIN:[loss=0.640] VALID:[accuracy=0.614]
# Saving model at iteration 77 with best score 0.614
# [78 bat (0.09 epo)]: TRAIN:[loss=0.676] VALID:[accuracy=0.596]
# [79 bat (0.10 epo)]: TRAIN:[loss=0.606] VALID:[accuracy=0.592]
# [80 bat (0.10 epo)]: TRAIN:[loss=0.786] VALID:[accuracy=0.588]
# [81 bat (0.10 epo)]: TRAIN:[loss=0.601] VALID:[accuracy=0.603]
# [82 bat (0.10 epo)]: TRAIN:[loss=0.668] VALID:[accuracy=0.606]
# [83 bat (0.10 epo)]: TRAIN:[loss=0.630] VALID:[accuracy=0.599]
# [84 bat (0.10 epo)]: TRAIN:[loss=0.640] VALID:[accuracy=0.625]
# Saving model at iteration 84 with best score 0.625
# [85 bat (0.10 epo)]: TRAIN:[loss=0.592] VALID:[accuracy=0.592]
# [86 bat (0.10 epo)]: TRAIN:[loss=0.659] VALID:[accuracy=0.585]
# [87 bat (0.10 epo)]: TRAIN:[loss=0.597] VALID:[accuracy=0.570]
# [88 bat (0.11 epo)]: TRAIN:[loss=0.623] VALID:[accuracy=0.567]
# [89 bat (0.11 epo)]: TRAIN:[loss=0.653] VALID:[accuracy=0.588]
# [90 bat (0.11 epo)]: TRAIN:[loss=0.659] VALID:[accuracy=0.639]
# Saving model at iteration 90 with best score 0.639
# [91 bat (0.11 epo)]: TRAIN:[loss=0.533] VALID:[accuracy=0.625]
# [92 bat (0.11 epo)]: TRAIN:[loss=0.615] VALID:[accuracy=0.628]
# [93 bat (0.11 epo)]: TRAIN:[loss=0.505] VALID:[accuracy=0.646]
# Saving model at iteration 93 with best score 0.646
# [94 bat (0.11 epo)]: TRAIN:[loss=0.541] VALID:[accuracy=0.625]
# [95 bat (0.11 epo)]: TRAIN:[loss=0.558] VALID:[accuracy=0.635]
# [96 bat (0.12 epo)]: TRAIN:[loss=0.552] VALID:[accuracy=0.643]
# [97 bat (0.12 epo)]: TRAIN:[loss=0.613] VALID:[accuracy=0.639]
# [98 bat (0.12 epo)]: TRAIN:[loss=0.612] VALID:[accuracy=0.632]
# [99 bat (0.12 epo)]: TRAIN:[loss=0.568] VALID:[accuracy=0.621]
# [100 bat (0.12 epo)]: TRAIN:[loss=0.585] VALID:[accuracy=0.625]
# [101 bat (0.12 epo)]: TRAIN:[loss=0.641] VALID:[accuracy=0.632]
# [102 bat (0.12 epo)]: TRAIN:[loss=0.561] VALID:[accuracy=0.657]
# Saving model at iteration 102 with best score 0.657
# [103 bat (0.12 epo)]: TRAIN:[loss=0.504] VALID:[accuracy=0.686]
# Saving model at iteration 103 with best score 0.686
# [104 bat (0.13 epo)]: TRAIN:[loss=0.554] VALID:[accuracy=0.700]
# Saving model at iteration 104 with best score 0.700
# [105 bat (0.13 epo)]: TRAIN:[loss=0.488] VALID:[accuracy=0.690]
# [106 bat (0.13 epo)]: TRAIN:[loss=0.423] VALID:[accuracy=0.682]
# [107 bat (0.13 epo)]: TRAIN:[loss=0.499] VALID:[accuracy=0.668]
# [108 bat (0.13 epo)]: TRAIN:[loss=0.481] VALID:[accuracy=0.671]
# [109 bat (0.13 epo)]: TRAIN:[loss=0.503] VALID:[accuracy=0.675]
# [110 bat (0.13 epo)]: TRAIN:[loss=0.577] VALID:[accuracy=0.671]
# [111 bat (0.13 epo)]: TRAIN:[loss=0.393] VALID:[accuracy=0.711]
# Saving model at iteration 111 with best score 0.711
# [112 bat (0.13 epo)]: TRAIN:[loss=0.487] VALID:[accuracy=0.711]
# [113 bat (0.14 epo)]: TRAIN:[loss=0.345] VALID:[accuracy=0.697]
# [114 bat (0.14 epo)]: TRAIN:[loss=0.656] VALID:[accuracy=0.693]
# [115 bat (0.14 epo)]: TRAIN:[loss=0.555] VALID:[accuracy=0.704]
# [116 bat (0.14 epo)]: TRAIN:[loss=0.441] VALID:[accuracy=0.700]
# [117 bat (0.14 epo)]: TRAIN:[loss=0.435] VALID:[accuracy=0.686]
# [118 bat (0.14 epo)]: TRAIN:[loss=0.393] VALID:[accuracy=0.668]
# [119 bat (0.14 epo)]: TRAIN:[loss=0.391] VALID:[accuracy=0.668]
# [120 bat (0.14 epo)]: TRAIN:[loss=0.299] VALID:[accuracy=0.646]
# [121 bat (0.15 epo)]: TRAIN:[loss=0.601] VALID:[accuracy=0.635]
# [122 bat (0.15 epo)]: TRAIN:[loss=0.380] VALID:[accuracy=0.635]
# [123 bat (0.15 epo)]: TRAIN:[loss=0.569] VALID:[accuracy=0.657]
# [124 bat (0.15 epo)]: TRAIN:[loss=0.480] VALID:[accuracy=0.664]
# [125 bat (0.15 epo)]: TRAIN:[loss=0.398] VALID:[accuracy=0.653]
# [126 bat (0.15 epo)]: TRAIN:[loss=0.541] VALID:[accuracy=0.657]
# [127 bat (0.15 epo)]: TRAIN:[loss=0.555] VALID:[accuracy=0.697]
# [128 bat (0.15 epo)]: TRAIN:[loss=0.398] VALID:[accuracy=0.653]
# [129 bat (0.16 epo)]: TRAIN:[loss=0.291] VALID:[accuracy=0.603]
# [130 bat (0.16 epo)]: TRAIN:[loss=0.456] VALID:[accuracy=0.606]
# [131 bat (0.16 epo)]: TRAIN:[loss=0.489] VALID:[accuracy=0.621]
# [132 bat (0.16 epo)]: TRAIN:[loss=0.427] VALID:[accuracy=0.643]
# [133 bat (0.16 epo)]: TRAIN:[loss=0.408] VALID:[accuracy=0.653]
# [134 bat (0.16 epo)]: TRAIN:[loss=0.501] VALID:[accuracy=0.643]
# [135 bat (0.16 epo)]: TRAIN:[loss=0.617] VALID:[accuracy=0.635]
# [136 bat (0.16 epo)]: TRAIN:[loss=0.676] VALID:[accuracy=0.650]
# [137 bat (0.17 epo)]: TRAIN:[loss=0.609] VALID:[accuracy=0.643]
# [138 bat (0.17 epo)]: TRAIN:[loss=0.548] VALID:[accuracy=0.639]
# [139 bat (0.17 epo)]: TRAIN:[loss=0.529] VALID:[accuracy=0.599]
# [140 bat (0.17 epo)]: TRAIN:[loss=0.338] VALID:[accuracy=0.588]
# [141 bat (0.17 epo)]: TRAIN:[loss=0.679] VALID:[accuracy=0.570]
# [142 bat (0.17 epo)]: TRAIN:[loss=0.526] VALID:[accuracy=0.578]
# [143 bat (0.17 epo)]: TRAIN:[loss=0.781] VALID:[accuracy=0.581]
# [144 bat (0.17 epo)]: TRAIN:[loss=0.730] VALID:[accuracy=0.599]
# [145 bat (0.17 epo)]: TRAIN:[loss=0.611] VALID:[accuracy=0.614]
# [146 bat (0.18 epo)]: TRAIN:[loss=0.579] VALID:[accuracy=0.617]
# [147 bat (0.18 epo)]: TRAIN:[loss=0.474] VALID:[accuracy=0.628]
# [148 bat (0.18 epo)]: TRAIN:[loss=0.578] VALID:[accuracy=0.632]
# [149 bat (0.18 epo)]: TRAIN:[loss=0.513] VALID:[accuracy=0.646]
# [150 bat (0.18 epo)]: TRAIN:[loss=0.571] VALID:[accuracy=0.617]
# [151 bat (0.18 epo)]: TRAIN:[loss=0.603] VALID:[accuracy=0.614]
# [152 bat (0.18 epo)]: TRAIN:[loss=0.530] VALID:[accuracy=0.628]
# [153 bat (0.18 epo)]: TRAIN:[loss=0.516] VALID:[accuracy=0.671]
# [154 bat (0.19 epo)]: TRAIN:[loss=0.487] VALID:[accuracy=0.682]
# [155 bat (0.19 epo)]: TRAIN:[loss=0.522] VALID:[accuracy=0.664]
# [156 bat (0.19 epo)]: TRAIN:[loss=0.367] VALID:[accuracy=0.646]
# [157 bat (0.19 epo)]: TRAIN:[loss=0.441] VALID:[accuracy=0.650]
# [158 bat (0.19 epo)]: TRAIN:[loss=0.575] VALID:[accuracy=0.650]
# [159 bat (0.19 epo)]: TRAIN:[loss=0.459] VALID:[accuracy=0.646]
# [160 bat (0.19 epo)]: TRAIN:[loss=0.511] VALID:[accuracy=0.653]
# [161 bat (0.19 epo)]: TRAIN:[loss=0.479] VALID:[accuracy=0.653]
# [162 bat (0.20 epo)]: TRAIN:[loss=0.508] VALID:[accuracy=0.646]
# [163 bat (0.20 epo)]: TRAIN:[loss=0.386] VALID:[accuracy=0.653]
# [164 bat (0.20 epo)]: TRAIN:[loss=0.455] VALID:[accuracy=0.646]
# [165 bat (0.20 epo)]: TRAIN:[loss=0.435] VALID:[accuracy=0.682]
# [166 bat (0.20 epo)]: TRAIN:[loss=0.408] VALID:[accuracy=0.675]
# [167 bat (0.20 epo)]: TRAIN:[loss=0.358] VALID:[accuracy=0.675]
# [168 bat (0.20 epo)]: TRAIN:[loss=0.430] VALID:[accuracy=0.686]
# [169 bat (0.20 epo)]: TRAIN:[loss=0.289] VALID:[accuracy=0.657]
# [170 bat (0.20 epo)]: TRAIN:[loss=0.411] VALID:[accuracy=0.653]
# [171 bat (0.21 epo)]: TRAIN:[loss=0.264] VALID:[accuracy=0.632]
# [172 bat (0.21 epo)]: TRAIN:[loss=0.312] VALID:[accuracy=0.632]
# [173 bat (0.21 epo)]: TRAIN:[loss=0.405] VALID:[accuracy=0.635]
# [174 bat (0.21 epo)]: TRAIN:[loss=0.355] VALID:[accuracy=0.632]
# [175 bat (0.21 epo)]: TRAIN:[loss=0.309] VALID:[accuracy=0.643]
# [176 bat (0.21 epo)]: TRAIN:[loss=0.466] VALID:[accuracy=0.653]
# [177 bat (0.21 epo)]: TRAIN:[loss=0.267] VALID:[accuracy=0.664]
# [178 bat (0.21 epo)]: TRAIN:[loss=0.275] VALID:[accuracy=0.664]
# [179 bat (0.22 epo)]: TRAIN:[loss=0.288] VALID:[accuracy=0.664]
# [180 bat (0.22 epo)]: TRAIN:[loss=0.269] VALID:[accuracy=0.668]
# [181 bat (0.22 epo)]: TRAIN:[loss=0.165] VALID:[accuracy=0.679]
# [182 bat (0.22 epo)]: TRAIN:[loss=0.212] VALID:[accuracy=0.675]
# [183 bat (0.22 epo)]: TRAIN:[loss=0.270] VALID:[accuracy=0.657]
# [184 bat (0.22 epo)]: TRAIN:[loss=0.214] VALID:[accuracy=0.661]
# [185 bat (0.22 epo)]: TRAIN:[loss=0.270] VALID:[accuracy=0.664]
# [186 bat (0.22 epo)]: TRAIN:[loss=0.241] VALID:[accuracy=0.682]
# [187 bat (0.23 epo)]: TRAIN:[loss=0.173] VALID:[accuracy=0.675]
# [188 bat (0.23 epo)]: TRAIN:[loss=0.263] VALID:[accuracy=0.661]
# [189 bat (0.23 epo)]: TRAIN:[loss=0.237] VALID:[accuracy=0.657]
# [190 bat (0.23 epo)]: TRAIN:[loss=0.267] VALID:[accuracy=0.664]
# [191 bat (0.23 epo)]: TRAIN:[loss=0.292] VALID:[accuracy=0.671]
# [192 bat (0.23 epo)]: TRAIN:[loss=0.346] VALID:[accuracy=0.657]
# [193 bat (0.23 epo)]: TRAIN:[loss=0.223] VALID:[accuracy=0.653]
# [194 bat (0.23 epo)]: TRAIN:[loss=0.235] VALID:[accuracy=0.653]
# [195 bat (0.23 epo)]: TRAIN:[loss=0.146] VALID:[accuracy=0.671]
# [196 bat (0.24 epo)]: TRAIN:[loss=0.202] VALID:[accuracy=0.682]
# [197 bat (0.24 epo)]: TRAIN:[loss=0.380] VALID:[accuracy=0.675]
# [198 bat (0.24 epo)]: TRAIN:[loss=0.112] VALID:[accuracy=0.686]
# [199 bat (0.24 epo)]: TRAIN:[loss=0.686] VALID:[accuracy=0.675]
# [200 bat (0.24 epo)]: TRAIN:[loss=0.351] VALID:[accuracy=0.693]
# [201 bat (0.24 epo)]: TRAIN:[loss=0.306] VALID:[accuracy=0.675]
# [202 bat (0.24 epo)]: TRAIN:[loss=0.274] VALID:[accuracy=0.682]
# [203 bat (0.24 epo)]: TRAIN:[loss=0.186] VALID:[accuracy=0.675]
# [204 bat (0.25 epo)]: TRAIN:[loss=0.195] VALID:[accuracy=0.668]
# [205 bat (0.25 epo)]: TRAIN:[loss=0.376] VALID:[accuracy=0.682]
# [206 bat (0.25 epo)]: TRAIN:[loss=0.300] VALID:[accuracy=0.690]
# [207 bat (0.25 epo)]: TRAIN:[loss=0.211] VALID:[accuracy=0.686]
# [208 bat (0.25 epo)]: TRAIN:[loss=0.241] VALID:[accuracy=0.671]
# [209 bat (0.25 epo)]: TRAIN:[loss=0.230] VALID:[accuracy=0.682]
# [210 bat (0.25 epo)]: TRAIN:[loss=0.191] VALID:[accuracy=0.686]
# [211 bat (0.25 epo)]: TRAIN:[loss=0.186] VALID:[accuracy=0.668]
# [212 bat (0.26 epo)]: TRAIN:[loss=0.165] VALID:[accuracy=0.661]
# [213 bat (0.26 epo)]: TRAIN:[loss=0.357] VALID:[accuracy=0.668]
# [214 bat (0.26 epo)]: TRAIN:[loss=0.191] VALID:[accuracy=0.664]
# [215 bat (0.26 epo)]: TRAIN:[loss=0.176] VALID:[accuracy=0.671]
# [216 bat (0.26 epo)]: TRAIN:[loss=0.248] VALID:[accuracy=0.697]
# [217 bat (0.26 epo)]: TRAIN:[loss=0.120] VALID:[accuracy=0.700]
# [218 bat (0.26 epo)]: TRAIN:[loss=0.141] VALID:[accuracy=0.697]
# [219 bat (0.26 epo)]: TRAIN:[loss=0.386] VALID:[accuracy=0.697]
# [220 bat (0.27 epo)]: TRAIN:[loss=0.185] VALID:[accuracy=0.682]
# [221 bat (0.27 epo)]: TRAIN:[loss=0.433] VALID:[accuracy=0.664]
# [222 bat (0.27 epo)]: TRAIN:[loss=0.367] VALID:[accuracy=0.661]
# [223 bat (0.27 epo)]: TRAIN:[loss=0.144] VALID:[accuracy=0.671]
# [224 bat (0.27 epo)]: TRAIN:[loss=0.243] VALID:[accuracy=0.668]
# [225 bat (0.27 epo)]: TRAIN:[loss=0.340] VALID:[accuracy=0.671]
# [226 bat (0.27 epo)]: TRAIN:[loss=0.138] VALID:[accuracy=0.668]
# [227 bat (0.27 epo)]: TRAIN:[loss=0.471] VALID:[accuracy=0.661]
# [228 bat (0.27 epo)]: TRAIN:[loss=0.280] VALID:[accuracy=0.668]
# [229 bat (0.28 epo)]: TRAIN:[loss=0.289] VALID:[accuracy=0.632]
# [230 bat (0.28 epo)]: TRAIN:[loss=0.318] VALID:[accuracy=0.614]
# [231 bat (0.28 epo)]: TRAIN:[loss=0.342] VALID:[accuracy=0.621]
# [232 bat (0.28 epo)]: TRAIN:[loss=0.426] VALID:[accuracy=0.671]
# [233 bat (0.28 epo)]: TRAIN:[loss=0.302] VALID:[accuracy=0.668]
# [234 bat (0.28 epo)]: TRAIN:[loss=0.221] VALID:[accuracy=0.650]
# [235 bat (0.28 epo)]: TRAIN:[loss=0.228] VALID:[accuracy=0.646]
# [236 bat (0.28 epo)]: TRAIN:[loss=0.454] VALID:[accuracy=0.646]
# [237 bat (0.29 epo)]: TRAIN:[loss=0.294] VALID:[accuracy=0.646]
# [238 bat (0.29 epo)]: TRAIN:[loss=0.411] VALID:[accuracy=0.664]
# [239 bat (0.29 epo)]: TRAIN:[loss=0.313] VALID:[accuracy=0.657]
# [240 bat (0.29 epo)]: TRAIN:[loss=0.345] VALID:[accuracy=0.657]
# [241 bat (0.29 epo)]: TRAIN:[loss=0.160] VALID:[accuracy=0.646]
# [242 bat (0.29 epo)]: TRAIN:[loss=0.190] VALID:[accuracy=0.635]
# [243 bat (0.29 epo)]: TRAIN:[loss=0.309] VALID:[accuracy=0.635]
# [244 bat (0.29 epo)]: TRAIN:[loss=0.130] VALID:[accuracy=0.639]
# [245 bat (0.30 epo)]: TRAIN:[loss=0.157] VALID:[accuracy=0.650]
# [246 bat (0.30 epo)]: TRAIN:[loss=0.167] VALID:[accuracy=0.661]
# [247 bat (0.30 epo)]: TRAIN:[loss=0.131] VALID:[accuracy=0.668]
# [248 bat (0.30 epo)]: TRAIN:[loss=0.114] VALID:[accuracy=0.675]
# [249 bat (0.30 epo)]: TRAIN:[loss=0.104] VALID:[accuracy=0.664]
# [250 bat (0.30 epo)]: TRAIN:[loss=0.323] VALID:[accuracy=0.650]
# [251 bat (0.30 epo)]: TRAIN:[loss=0.164] VALID:[accuracy=0.650]
# [252 bat (0.30 epo)]: TRAIN:[loss=0.138] VALID:[accuracy=0.653]
# [253 bat (0.30 epo)]: TRAIN:[loss=0.204] VALID:[accuracy=0.653]
# [254 bat (0.31 epo)]: TRAIN:[loss=0.248] VALID:[accuracy=0.653]
# [255 bat (0.31 epo)]: TRAIN:[loss=0.136] VALID:[accuracy=0.653]
# [256 bat (0.31 epo)]: TRAIN:[loss=0.129] VALID:[accuracy=0.657]
# [257 bat (0.31 epo)]: TRAIN:[loss=0.127] VALID:[accuracy=0.657]
# [258 bat (0.31 epo)]: TRAIN:[loss=0.161] VALID:[accuracy=0.653]
# [259 bat (0.31 epo)]: TRAIN:[loss=0.097] VALID:[accuracy=0.653]
# [260 bat (0.31 epo)]: TRAIN:[loss=0.128] VALID:[accuracy=0.653]
# [261 bat (0.31 epo)]: TRAIN:[loss=0.204] VALID:[accuracy=0.650]
# [262 bat (0.32 epo)]: TRAIN:[loss=0.052] VALID:[accuracy=0.643]
# [263 bat (0.32 epo)]: TRAIN:[loss=0.042] VALID:[accuracy=0.650]
# [264 bat (0.32 epo)]: TRAIN:[loss=0.136] VALID:[accuracy=0.657]
# [265 bat (0.32 epo)]: TRAIN:[loss=0.184] VALID:[accuracy=0.650]
# [266 bat (0.32 epo)]: TRAIN:[loss=0.252] VALID:[accuracy=0.646]
# [267 bat (0.32 epo)]: TRAIN:[loss=0.057] VALID:[accuracy=0.643]
# [268 bat (0.32 epo)]: TRAIN:[loss=0.145] VALID:[accuracy=0.643]
# [269 bat (0.32 epo)]: TRAIN:[loss=0.101] VALID:[accuracy=0.639]
# [270 bat (0.33 epo)]: TRAIN:[loss=0.319] VALID:[accuracy=0.646]
# [271 bat (0.33 epo)]: TRAIN:[loss=0.146] VALID:[accuracy=0.661]
# [272 bat (0.33 epo)]: TRAIN:[loss=0.128] VALID:[accuracy=0.664]
# [273 bat (0.33 epo)]: TRAIN:[loss=0.049] VALID:[accuracy=0.639]
# [274 bat (0.33 epo)]: TRAIN:[loss=0.034] VALID:[accuracy=0.643]
# [275 bat (0.33 epo)]: TRAIN:[loss=0.322] VALID:[accuracy=0.657]
# [276 bat (0.33 epo)]: TRAIN:[loss=0.299] VALID:[accuracy=0.679]
# [277 bat (0.33 epo)]: TRAIN:[loss=0.315] VALID:[accuracy=0.671]
# [278 bat (0.33 epo)]: TRAIN:[loss=0.223] VALID:[accuracy=0.671]
# [279 bat (0.34 epo)]: TRAIN:[loss=0.598] VALID:[accuracy=0.675]
# [280 bat (0.34 epo)]: TRAIN:[loss=0.187] VALID:[accuracy=0.671]
# [281 bat (0.34 epo)]: TRAIN:[loss=0.063] VALID:[accuracy=0.650]
# [282 bat (0.34 epo)]: TRAIN:[loss=0.260] VALID:[accuracy=0.628]
# [283 bat (0.34 epo)]: TRAIN:[loss=0.231] VALID:[accuracy=0.610]
# [284 bat (0.34 epo)]: TRAIN:[loss=0.283] VALID:[accuracy=0.621]
# [285 bat (0.34 epo)]: TRAIN:[loss=0.264] VALID:[accuracy=0.639]
# [286 bat (0.34 epo)]: TRAIN:[loss=0.137] VALID:[accuracy=0.671]
# [287 bat (0.35 epo)]: TRAIN:[loss=0.193] VALID:[accuracy=0.661]
# [288 bat (0.35 epo)]: TRAIN:[loss=0.131] VALID:[accuracy=0.668]
# [289 bat (0.35 epo)]: TRAIN:[loss=0.052] VALID:[accuracy=0.679]
# [290 bat (0.35 epo)]: TRAIN:[loss=0.211] VALID:[accuracy=0.661]
# [291 bat (0.35 epo)]: TRAIN:[loss=0.224] VALID:[accuracy=0.664]
# [292 bat (0.35 epo)]: TRAIN:[loss=0.039] VALID:[accuracy=0.661]
# [293 bat (0.35 epo)]: TRAIN:[loss=0.157] VALID:[accuracy=0.664]
# [294 bat (0.35 epo)]: TRAIN:[loss=0.260] VALID:[accuracy=0.661]
# [295 bat (0.36 epo)]: TRAIN:[loss=0.037] VALID:[accuracy=0.646]
# [296 bat (0.36 epo)]: TRAIN:[loss=0.073] VALID:[accuracy=0.646]
# [297 bat (0.36 epo)]: TRAIN:[loss=0.231] VALID:[accuracy=0.643]
# [298 bat (0.36 epo)]: TRAIN:[loss=0.275] VALID:[accuracy=0.643]
# [299 bat (0.36 epo)]: TRAIN:[loss=0.151] VALID:[accuracy=0.650]
# [300 bat (0.36 epo)]: TRAIN:[loss=0.146] VALID:[accuracy=0.661]
# [301 bat (0.36 epo)]: TRAIN:[loss=0.173] VALID:[accuracy=0.661]
# [302 bat (0.36 epo)]: TRAIN:[loss=0.186] VALID:[accuracy=0.653]
# [303 bat (0.37 epo)]: TRAIN:[loss=0.264] VALID:[accuracy=0.646]
# [304 bat (0.37 epo)]: TRAIN:[loss=0.040] VALID:[accuracy=0.650]
# [305 bat (0.37 epo)]: TRAIN:[loss=0.160] VALID:[accuracy=0.650]
# [306 bat (0.37 epo)]: TRAIN:[loss=0.090] VALID:[accuracy=0.668]
# [307 bat (0.37 epo)]: TRAIN:[loss=0.298] VALID:[accuracy=0.661]
# [308 bat (0.37 epo)]: TRAIN:[loss=0.131] VALID:[accuracy=0.653]
# [309 bat (0.37 epo)]: TRAIN:[loss=0.267] VALID:[accuracy=0.643]
# [310 bat (0.37 epo)]: TRAIN:[loss=0.039] VALID:[accuracy=0.625]
# [311 bat (0.37 epo)]: TRAIN:[loss=0.142] VALID:[accuracy=0.610]
# [312 bat (0.38 epo)]: TRAIN:[loss=0.433] VALID:[accuracy=0.614]
# [313 bat (0.38 epo)]: TRAIN:[loss=0.828] VALID:[accuracy=0.635]
# [314 bat (0.38 epo)]: TRAIN:[loss=0.121] VALID:[accuracy=0.671]
# [315 bat (0.38 epo)]: TRAIN:[loss=0.415] VALID:[accuracy=0.668]
# [316 bat (0.38 epo)]: TRAIN:[loss=0.047] VALID:[accuracy=0.646]
# [317 bat (0.38 epo)]: TRAIN:[loss=0.269] VALID:[accuracy=0.621]
# [318 bat (0.38 epo)]: TRAIN:[loss=0.285] VALID:[accuracy=0.603]
# [319 bat (0.38 epo)]: TRAIN:[loss=0.213] VALID:[accuracy=0.599]
# [320 bat (0.39 epo)]: TRAIN:[loss=0.449] VALID:[accuracy=0.603]
# [321 bat (0.39 epo)]: TRAIN:[loss=0.568] VALID:[accuracy=0.646]
# [322 bat (0.39 epo)]: TRAIN:[loss=0.257] VALID:[accuracy=0.657]
# [323 bat (0.39 epo)]: TRAIN:[loss=0.378] VALID:[accuracy=0.657]
# [324 bat (0.39 epo)]: TRAIN:[loss=0.129] VALID:[accuracy=0.646]
# [325 bat (0.39 epo)]: TRAIN:[loss=0.151] VALID:[accuracy=0.646]
# [326 bat (0.39 epo)]: TRAIN:[loss=0.300] VALID:[accuracy=0.628]
# [327 bat (0.39 epo)]: TRAIN:[loss=0.342] VALID:[accuracy=0.614]
# [328 bat (0.40 epo)]: TRAIN:[loss=0.261] VALID:[accuracy=0.617]
# [329 bat (0.40 epo)]: TRAIN:[loss=0.135] VALID:[accuracy=0.639]
# [330 bat (0.40 epo)]: TRAIN:[loss=0.240] VALID:[accuracy=0.650]
# [331 bat (0.40 epo)]: TRAIN:[loss=0.143] VALID:[accuracy=0.653]
# [332 bat (0.40 epo)]: TRAIN:[loss=0.134] VALID:[accuracy=0.668]
# [333 bat (0.40 epo)]: TRAIN:[loss=0.147] VALID:[accuracy=0.686]
# [334 bat (0.40 epo)]: TRAIN:[loss=0.117] VALID:[accuracy=0.686]
# [335 bat (0.40 epo)]: TRAIN:[loss=0.138] VALID:[accuracy=0.675]
# [336 bat (0.40 epo)]: TRAIN:[loss=0.126] VALID:[accuracy=0.668]
# [337 bat (0.41 epo)]: TRAIN:[loss=0.124] VALID:[accuracy=0.668]
# [338 bat (0.41 epo)]: TRAIN:[loss=0.252] VALID:[accuracy=0.664]
# [339 bat (0.41 epo)]: TRAIN:[loss=0.066] VALID:[accuracy=0.671]
# [340 bat (0.41 epo)]: TRAIN:[loss=0.101] VALID:[accuracy=0.686]
# [341 bat (0.41 epo)]: TRAIN:[loss=0.104] VALID:[accuracy=0.690]
# [342 bat (0.41 epo)]: TRAIN:[loss=0.216] VALID:[accuracy=0.668]
# [343 bat (0.41 epo)]: TRAIN:[loss=0.102] VALID:[accuracy=0.682]
# [344 bat (0.41 epo)]: TRAIN:[loss=0.101] VALID:[accuracy=0.686]
# [345 bat (0.42 epo)]: TRAIN:[loss=0.057] VALID:[accuracy=0.686]
# [346 bat (0.42 epo)]: TRAIN:[loss=0.153] VALID:[accuracy=0.686]
# [347 bat (0.42 epo)]: TRAIN:[loss=0.046] VALID:[accuracy=0.679]
# [348 bat (0.42 epo)]: TRAIN:[loss=0.206] VALID:[accuracy=0.682]
# [349 bat (0.42 epo)]: TRAIN:[loss=0.054] VALID:[accuracy=0.686]
# [350 bat (0.42 epo)]: TRAIN:[loss=0.162] VALID:[accuracy=0.668]
# [351 bat (0.42 epo)]: TRAIN:[loss=0.112] VALID:[accuracy=0.686]
# [352 bat (0.42 epo)]: TRAIN:[loss=0.074] VALID:[accuracy=0.682]
# [353 bat (0.43 epo)]: TRAIN:[loss=0.156] VALID:[accuracy=0.682]
# [354 bat (0.43 epo)]: TRAIN:[loss=0.121] VALID:[accuracy=0.682]
# [355 bat (0.43 epo)]: TRAIN:[loss=0.127] VALID:[accuracy=0.679]
# [356 bat (0.43 epo)]: TRAIN:[loss=0.021] VALID:[accuracy=0.675]
# [357 bat (0.43 epo)]: TRAIN:[loss=0.130] VALID:[accuracy=0.682]
# [358 bat (0.43 epo)]: TRAIN:[loss=0.174] VALID:[accuracy=0.693]
# [359 bat (0.43 epo)]: TRAIN:[loss=0.062] VALID:[accuracy=0.690]
# [360 bat (0.43 epo)]: TRAIN:[loss=0.117] VALID:[accuracy=0.686]
# [361 bat (0.43 epo)]: TRAIN:[loss=0.234] VALID:[accuracy=0.686]
# [362 bat (0.44 epo)]: TRAIN:[loss=0.311] VALID:[accuracy=0.679]
# [363 bat (0.44 epo)]: TRAIN:[loss=0.108] VALID:[accuracy=0.693]
# [364 bat (0.44 epo)]: TRAIN:[loss=0.126] VALID:[accuracy=0.686]
# [365 bat (0.44 epo)]: TRAIN:[loss=0.136] VALID:[accuracy=0.686]
# [366 bat (0.44 epo)]: TRAIN:[loss=0.120] VALID:[accuracy=0.679]
# [367 bat (0.44 epo)]: TRAIN:[loss=0.052] VALID:[accuracy=0.679]
# [368 bat (0.44 epo)]: TRAIN:[loss=0.122] VALID:[accuracy=0.679]
# [369 bat (0.44 epo)]: TRAIN:[loss=0.153] VALID:[accuracy=0.682]
# [370 bat (0.45 epo)]: TRAIN:[loss=0.032] VALID:[accuracy=0.682]
# [371 bat (0.45 epo)]: TRAIN:[loss=0.149] VALID:[accuracy=0.693]
# [372 bat (0.45 epo)]: TRAIN:[loss=0.191] VALID:[accuracy=0.697]
# [373 bat (0.45 epo)]: TRAIN:[loss=0.219] VALID:[accuracy=0.697]
# [374 bat (0.45 epo)]: TRAIN:[loss=0.064] VALID:[accuracy=0.693]
# [375 bat (0.45 epo)]: TRAIN:[loss=0.106] VALID:[accuracy=0.679]
# [376 bat (0.45 epo)]: TRAIN:[loss=0.121] VALID:[accuracy=0.682]
# [377 bat (0.45 epo)]: TRAIN:[loss=0.196] VALID:[accuracy=0.690]
# [378 bat (0.46 epo)]: TRAIN:[loss=0.070] VALID:[accuracy=0.697]
# [379 bat (0.46 epo)]: TRAIN:[loss=0.114] VALID:[accuracy=0.693]
# [380 bat (0.46 epo)]: TRAIN:[loss=0.208] VALID:[accuracy=0.697]
# [381 bat (0.46 epo)]: TRAIN:[loss=0.092] VALID:[accuracy=0.693]
# [382 bat (0.46 epo)]: TRAIN:[loss=0.063] VALID:[accuracy=0.675]
# [383 bat (0.46 epo)]: TRAIN:[loss=0.077] VALID:[accuracy=0.661]
# [384 bat (0.46 epo)]: TRAIN:[loss=0.106] VALID:[accuracy=0.664]
# [385 bat (0.46 epo)]: TRAIN:[loss=0.280] VALID:[accuracy=0.671]
# [386 bat (0.47 epo)]: TRAIN:[loss=0.251] VALID:[accuracy=0.679]
# [387 bat (0.47 epo)]: TRAIN:[loss=0.294] VALID:[accuracy=0.704]
# [388 bat (0.47 epo)]: TRAIN:[loss=0.148] VALID:[accuracy=0.697]
# [389 bat (0.47 epo)]: TRAIN:[loss=0.071] VALID:[accuracy=0.668]
# [390 bat (0.47 epo)]: TRAIN:[loss=0.023] VALID:[accuracy=0.664]
# Restoring best model from iteration 111 with score 0.711
# Finished Training
# Accuracy: 0.711
#         y=1    y=2
#  l=1    119    27
#  l=2    53     78

# %%
# Test end model
end_model.score(dataloaders["dev"], metric=["accuracy", "precision", "recall", "f1"])
# Out:
# Accuracy: 0.711
# Precision: 0.692
# Recall: 0.815
# F1: 0.748
#         y=1    y=2
#  l=1    119    27
#  l=2    53     78
# [0.7111913357400722, 0.6918604651162791, 0.815068493150685, 0.7484276729559748]
