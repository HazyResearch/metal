# %% [markdown]
# ## Working, but ugly :(

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, Dataset
import numpy as np
import pandas as pd
import metal
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM
from metal.end_model import EndModel
import torch.nn as nn

# %%
from modules import BertEncoder, createBertDataloader, BertMulticlassHead, BertBinaryHead

# %%
dataloaders = createBertDataloader('SST-2',batch_sz=8, sent1_idx=0, sent2_idx=-1, label_idx=1, header=1, label_fn = lambda x: int(x)+1)
# Out:
#   0%|          | 0/67349 [00:00<?, ?it/s]
#
#
#
#
#
#   1%|          | 342/67349 [00:00<00:19, 3418.49it/s]
#
#
#
#
#
#   1%|          | 687/67349 [00:00<00:19, 3426.81it/s]
#
#
#
#
#
#   2%|▏         | 1020/67349 [00:00<00:19, 3395.71it/s]
#
#
#
#
#
#   2%|▏         | 1366/67349 [00:00<00:19, 3411.42it/s]
#
#
#
#
#
#   3%|▎         | 1708/67349 [00:00<00:19, 3407.93it/s]
#
#
#
#
#
#   3%|▎         | 2060/67349 [00:00<00:18, 3439.54it/s]
#
#
#
#
#
#   4%|▎         | 2385/67349 [00:00<00:19, 3379.00it/s]
#
#
#
#
#
#   4%|▍         | 2736/67349 [00:00<00:18, 3414.96it/s]
#
#
#
#
#
#   5%|▍         | 3079/67349 [00:00<00:18, 3416.70it/s]
#
#
#
#
#
#   5%|▌         | 3408/67349 [00:01<00:18, 3370.02it/s]
#
#
#
#
#
#   6%|▌         | 3739/67349 [00:01<00:18, 3350.23it/s]
#
#
#
#
#
#   6%|▌         | 4092/67349 [00:01<00:18, 3394.39it/s]
#
#
#
#
#
#   7%|▋         | 4428/67349 [00:01<00:18, 3379.03it/s]
#
#
#
#
#
#   7%|▋         | 4763/67349 [00:01<00:18, 3345.90it/s]
#
#
#
#
#
# ...

# %%
encoder_module = BertEncoder()
end_model = EndModel(
    [768, 2],
    input_module=encoder_module,
    seed=123,
    device = torch.device("cuda:0"),
    skip_head=False,
    input_relu=False,
    input_batchnorm=False,
    verbose=False
)

# %%
end_model.train_model(dataloaders[0], valid_data=dataloaders[1],
                      lr=0.01, l2=0.01, 
                      n_epochs=5, checkpoint_metric='accuracy',
                      log_valid_metrics=["model/train/loss", "valid/loss"],
                      checkpoint_metric_mode='max',
                      verbose=True, progress_bar=True
                    )
# Out:
# Using GPU...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-43ae40311b99> in <module>
#       4                       log_valid_metrics=["model/train/loss", "valid/loss"],
#       5                       checkpoint_metric_mode='max',
# ----> 6                       verbose=True, progress_bar=True
#       7                     )
#
# /lfs/local/0/mccreery/repos/metal/metal/end_model/end_model.py in train_model(self, train_data, valid_data, log_writer, **kwargs)
#     215         # Execute training procedure
#     216         self._train_model(
# --> 217             train_loader, loss_fn, valid_data=valid_data, log_writer=log_writer
#     218         )
#     219
#
# /lfs/local/0/mccreery/repos/metal/metal/classifier.py in _train_model(self, train_data, loss_fn, valid_data, log_writer, restore_state)
#     242
# ...
